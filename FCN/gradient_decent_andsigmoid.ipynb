# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices)!=0: #Use GPU for better experience
  tf.config.experimental.set_memory_growth(physical_devices[0],True)
print(physical_devices)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
(x_train,y_train), (x_test,y_test) = mnist.load_data()
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000,)
# (10000,)

# %% [markdown]
# Kiểm tra xem tập train có bị bias không

# %%
fig, axes = plt.subplots(10, 10, figsize=(10, 10))
fig.subplots_adjust(hspace=0.3, wspace=0.3)

for label in range(10):
    indices = np.where(y_train == label)[0][:10]
    for i, idx in enumerate(indices):
        ax = axes[label, i]
        ax.imshow(x_train[idx], cmap='gray')
        ax.axis('off')

plt.show()

# %%
train_label_counts = np.bincount(y_train, minlength=10)
test_label_counts = np.bincount(y_test, minlength=10)

fig, ax = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle('Distribution of Labels in the MNIST Dataset')

ax[0].bar(range(10), train_label_counts, color='skyblue')
ax[0].set_xlabel('Label')
ax[0].set_ylabel('Frequency')
ax[0].set_title('Training Set')
ax[0].set_xticks(range(10))
ax[0].set_ylim(4000, max(train_label_counts) + 500)
for i, count in enumerate(train_label_counts):
    ax[0].text(i, count + 100, str(count), ha='center', color='black', fontsize=12)

ax[1].bar(range(10), test_label_counts, color='salmon')
ax[1].set_xlabel('Label')
ax[1].set_title('Test Set')
ax[1].set_xticks(range(10))
ax[1].set_ylim(600, max(test_label_counts) + 100)
for i, count in enumerate(test_label_counts):
    ax[1].text(i, count + 20, str(count), ha='center', color='black', fontsize=12)

plt.show()

# %%
x_train = x_train.astype('float32')/255.0
x_test = x_test.astype('float32')/255.0

# %%
print(x_train.shape)
print(type(x_train))
print(max(x_train.flatten()),min(x_train.flatten()))
print(x_test.shape)
print(type(x_test))
print(max(x_test.flatten()),min(x_test.flatten()))
# Out:
# (60000, 28, 28)
# <class 'numpy.ndarray'>
# 1.0 0.0
# (10000, 28, 28)
# <class 'numpy.ndarray'>
# 1.0 0.0

# %%
from scipy.ndimage import rotate, gaussian_filter

#Rotation 30 deg maximum, just to make sure the labels wont mess up such as 9 and 6 or 2 and 5 or even 1 and 7
def random_rotate_image_2d(image, max_angle=30):
    angle = np.random.uniform(-max_angle, max_angle)
    rotated_image = rotate(image, angle, reshape=False, mode='nearest')
    return rotated_image

#Shift images horizontaly or vertically a few pixels
def shift_image(image, max_offset=3):
    offset_x = np.random.randint(-max_offset, max_offset + 1)
    offset_y = np.random.randint(-max_offset, max_offset + 1)
    return np.roll(np.roll(image.reshape(28, 28), offset_x, axis=1), offset_y, axis=0)

#Add gaussian noise
def add_gaussian_noise(image, mean=0,std=0.1):
    noise = np.random.normal(mean, std, image.shape)
    return np.clip(image + noise, 0, 1) #Remember to use with the normalized image pumpkin

def reduce_noise(image, sigma=0.5):
  return gaussian_filter(image, sigma=sigma)

def augment(image):
  image = random_rotate_image_2d(image)
  image = shift_image(image)
  image = add_gaussian_noise(image)
  image = reduce_noise(image)
  return image

# %%
num_images = 5

plt.figure(figsize=(10, 4))

for i in range(num_images):
    idx = np.random.randint(0, x_train.shape[0])
    original_image = x_train[idx]
    augmented_image = augment(original_image)

    plt.subplot(2, num_images, i + 1)
    plt.imshow(original_image, cmap='gray')
    plt.axis('off')
    plt.title("Original")

    plt.subplot(2, num_images, num_images + i + 1)
    plt.imshow(augmented_image, cmap='gray')
    plt.axis('off')
    plt.title("Augmented")

plt.tight_layout()
plt.show()

# %%
x_train = np.array([augment(image) for image in x_train])

# %%
fig, axes = plt.subplots(10, 10, figsize=(10, 10))
fig.subplots_adjust(hspace=0.3, wspace=0.3)

for label in range(10):
    indices = np.where(y_train == label)[0][:10]
    for i, idx in enumerate(indices):
        ax = axes[label, i]
        ax.imshow(x_train[idx], cmap='gray')
        ax.axis('off')

plt.show()

# %%
x_train = x_train.reshape(-1,28*28)
x_test = x_test.reshape(-1,28*28)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
param_grid = {
    'learning_rate': [0.00001,0.0001,0.001],
    'hidden_size_layer1': [2,4,8,16,32,64],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32, 64, 128],
    'weight_decay':[0.00001],
    'epochs': [5000]#vì dùng early stop nên cho một số epochs to hẳn
}

# %% [markdown]
# Cấu hình để thử từng trường hợp nhằm tìm ra chỉ số có accuracy tốt nhất

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# Tách tập train thành 2 tập là train và valid

# %%
train_label_counts = np.bincount(y_train, minlength=10)
val_label_counts = np.bincount(y_val, minlength=10)

fig, ax = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle('Distribution of Labels in the MNIST Dataset')

ax[0].bar(range(10), train_label_counts, color='skyblue')
ax[0].set_xlabel('Label')
ax[0].set_ylabel('Frequency')
ax[0].set_title('Training Set')
ax[0].set_xticks(range(10))
ax[0].set_ylim(4000, max(train_label_counts) + 500)
for i, count in enumerate(train_label_counts):
    ax[0].text(i, count + 100, str(count), ha='center', color='black', fontsize=12)

ax[1].bar(range(10), val_label_counts, color='salmon')
ax[1].set_xlabel('Label')
ax[1].set_title('Val Set')
ax[1].set_xticks(range(10))
ax[1].set_ylim(600, max(test_label_counts) + 100)
for i, count in enumerate(test_label_counts):
    ax[1].text(i, count + 20, str(count), ha='center', color='black', fontsize=12)

plt.show()

# %%
print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
# Out:
# (48000, 784)
# (48000,)
# (12000, 784)
# (12000,)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False)
y_train_one_hot = encoder.fit_transform(y_train.reshape(-1, 1))
y_val_one_hot = encoder.transform(y_val.reshape(-1, 1))
y_test_one_hot = encoder.transform(y_test.reshape(-1, 1))

# %% [markdown]
# chuyển đổi mảng Y từ mảng 1 chiều sang mảng n chiều mỗi chiều có 10 phần tử tượng chưng cho 10 số (ví dụ số 0 là 1 0 0 0 ...,1 là 0 1 0 0 ...)

# %%
print(y_train_one_hot.shape)
print(y_val_one_hot.shape)
print(y_test_one_hot.shape)
# Out:
# (48000, 10)
# (12000, 10)
# (10000, 10)

# %%
import numpy as np

class SimpleNN:
    def __init__(self, input_size, hidden_size_layer1, hidden_size_layer2=None, hidden_size_layer3=None, output_size=1, learning_rate=0.01, l2_lambda=0.001):
        self.learning_rate = learning_rate
        self.layers = []
        self.A_prev = []  # Dùng để lưu các kết quả
        self.l2_lambda = l2_lambda

        # Khởi tạo trọng số với Xavier Initialization
        self.layers.append(np.random.randn(input_size, hidden_size_layer1) * np.sqrt(2 / (input_size + hidden_size_layer1)))

        if hidden_size_layer2 is not None:
            self.layers.append(np.random.randn(hidden_size_layer1, hidden_size_layer2) * np.sqrt(2 / (hidden_size_layer1 + hidden_size_layer2)))

        if hidden_size_layer3 is not None:
            self.layers.append(np.random.randn(hidden_size_layer2 if hidden_size_layer2 is not None else hidden_size_layer1, hidden_size_layer3) * np.sqrt(2 / ((hidden_size_layer2 if hidden_size_layer2 is not None else hidden_size_layer1) + hidden_size_layer3)))

        self.W_output = np.random.randn((hidden_size_layer3 if hidden_size_layer3 is not None else (hidden_size_layer2 if hidden_size_layer2 is not None else hidden_size_layer1)), output_size) * np.sqrt(2 / ((hidden_size_layer3 if hidden_size_layer3 is not None else (hidden_size_layer2 if hidden_size_layer2 is not None else hidden_size_layer1)) + output_size))

    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def sigmoid_derivative(self, z):
        return z * (1 - z)

    def soft_max(self, z):
        z_max = np.max(z, axis=1, keepdims=True)  # Tìm giá trị lớn nhất
        e_z = np.exp(z - z_max)  # Trừ giá trị lớn nhất
        return e_z / np.sum(e_z, axis=1, keepdims=True)  # Tính softmax

    def loss_function(self, output, y):
        return -np.sum(y * np.log(output)) / y.shape[0] + self.l2_lambda * np.sum([np.sum(np.square(layer)) for layer in self.layers]) + self.l2_lambda * np.sum(np.square(self.W_output))

    def forward(self, X):
        self.A = X
        self.A_prev = []

        for W in self.layers:
            self.Z = np.dot(self.A, W)
            self.A = self.sigmoid(self.Z)
            self.A_prev.append(self.A)

        self.Z_output = np.dot(self.A, self.W_output)
        self.A_output = self.soft_max(self.Z_output)
        return self.A_output

    def backward(self, X, y):
        output_delta = self.A_output - y
        self.W_output -= (self.A.T.dot(output_delta) + 2 * self.l2_lambda * self.W_output) * self.learning_rate

        hidden_delta = output_delta.dot(self.W_output.T) * self.sigmoid_derivative(self.A_prev[-1])

        for i in reversed(range(len(self.layers))):
            if i == 0:
                self.layers[i] -= (X.T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]) * self.learning_rate
            else:
                self.layers[i] -= (self.A_prev[i - 1].T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]) * self.learning_rate

            if i > 0:
                hidden_delta = hidden_delta.dot(self.layers[i].T) * self.sigmoid_derivative(self.A_prev[i - 1])

    def train(self, X, y, epochs):
        for epoch in range(epochs):
            self.forward(X)
            self.backward(X, y)

    def evaluate(self, X, y):
        output = self.forward(X)
        predictions = np.argmax(output, axis=1)
        true_labels = np.argmax(y, axis=1)
        accuracy = np.mean(predictions == true_labels)
        loss = self.loss_function(output, y)
        return accuracy, loss

# %% [markdown]
# Tạo mạng
# +) công thức tính hàm cross-entropy(chưa phạt L2) và đạo hàm của hàm cross-entropy
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_model(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs,weight_decay, patience=5, min_delta=0.001):
    model = SimpleNN(input_size=784,
                     hidden_size_layer1=hidden_size_layer1,
                     hidden_size_layer2=hidden_size_layer2,
                     hidden_size_layer3=hidden_size_layer3,
                     output_size=10,
                     learning_rate=learning_rate,
                     l2_lambda=weight_decay)
    best_accuracy = 0
    best_loss = float('inf')
    patience_counter = 0
    num_batches = int(np.ceil(len(x_train) / batch_size))

    for epoch in range(epochs):
        for i in range(num_batches):
            batch_x = x_train[i * batch_size:(i + 1) * batch_size]
            batch_y = y_train_one_hot[i * batch_size:(i + 1) * batch_size]
            model.train(batch_x, batch_y, 1)

        # Đánh giá độ chính xác và loss trên tập validation
        val_accuracy, val_loss = model.evaluate(x_val, y_val_one_hot)

        # Kiểm tra điều kiện early stopping
        if val_loss < best_loss - min_delta:
            best_loss = min(best_loss, val_loss)
            best_accuracy = max(best_accuracy, val_accuracy)
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f'Early stopping at epoch {epoch + 1}')
                break

        # Thông báo nếu loss đạt ngưỡng rất thấp
        if val_loss < 1e-8:
            print(f'Early stopping at epoch {epoch + 1} because loss_function is very low: {val_loss}')
            break

    # Đánh giá mô hình trên tập huấn luyện và tập xác thực
    train_accuracy, train_loss = model.evaluate(x_train, y_train_one_hot)
    val_accuracy, val_loss = model.evaluate(x_val, y_val_one_hot)

    # Dự đoán và tính các chỉ số trên tập huấn luyện và tập validation
    train_predictions = model.forward(x_train)
    val_predictions = model.forward(x_val)
    train_predictions_labels = np.argmax(train_predictions, axis=1)
    val_predictions_labels = np.argmax(val_predictions, axis=1)
    true_labels_train = np.argmax(y_train_one_hot, axis=1)
    true_labels_val = np.argmax(y_val_one_hot, axis=1)

    # Tính toán precision, recall, và F1-score
    precision = precision_score(true_labels_val, val_predictions_labels, average='weighted', zero_division=0)
    recall = recall_score(true_labels_val, val_predictions_labels, average='weighted')
    f1 = f1_score(true_labels_val, val_predictions_labels, average='weighted')

    return train_accuracy, val_accuracy, precision, recall, f1, train_loss, val_loss

# %% [markdown]
# xây dựng hàm đánh giá áp dụng early stop với patience là 5 tức là khi độ chính xác không tăng trong 5 lần liên tiếp sẽ lập tức dừng

# %% [markdown]
# # BẮT ĐẦU TÌM KIẾM HYPERPARAMS với một vài số ngẫu nhiên

# %%
param_grid = {
    'learning_rate': [0.0001,0.001],
    'hidden_size_layer1': [2,4,8,16,32,64],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32, 64, 128],
    'weight_decay':[0.00001,0.0001],
    'epochs': [5000]#vì dùng early stop nên cho một số epochs to hẳn
}
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 271
# Learning Rate: 0.0001, Hidden Sizes: 2, None, None, Batch Size: 32, Training Accuracy: 24.00%, Validation Accuracy: 24.36%, Precision: 13.10%, Recall: 24.36%, F1: 15.12%,loss_train:1.9740604302507916,loss_val:1.9810485552086925,weight_decay:1e-05
# Early stopping at epoch 190
# Learning Rate: 0.0001, Hidden Sizes: 2, None, None, Batch Size: 64, Training Accuracy: 28.74%, Validation Accuracy: 27.96%, Precision: 15.99%, Recall: 27.96%, F1: 19.71%,loss_train:1.9096202237844246,loss_val:1.9264642711585775,weight_decay:1e-05
# Early stopping at epoch 296
# Learning Rate: 0.0001, Hidden Sizes: 2, None, None, Batch Size: 128, Training Accuracy: 29.96%, Validation Accuracy: 29.11%, Precision: 14.42%, Recall: 29.11%, F1: 18.83%,loss_train:1.9040542935998244,loss_val:1.9257290454133682,weight_decay:1e-05
# Early stopping at epoch 305
# Learning Rate: 0.0001, Hidden Sizes: 4, None, None, Batch Size: 32, Training Accuracy: 47.24%, Validation Accuracy: 45.93%, Precision: 39.92%, Recall: 45.93%, F1: 41.72%,loss_train:1.5002841889065617,loss_val:1.5319325109072055,weight_decay:1e-05
# Early stopping at epoch 292
# Learning Rate: 0.0001, Hidden Sizes: 4, None, None, Batch Size: 64, Training Accuracy: 47.65%, Validation Accuracy: 47.12%, Precision: 41.32%, Recall: 47.12%, F1: 43.38%,loss_train:1.4881393775498029,loss_val:1.510175659669432,weight_decay:1e-05
# Early stopping at epoch 253
# Learning Rate: 0.0001, Hidden Sizes: 4, None, None, Batch Size: 128, Training Accuracy: 47.64%, Validation Accuracy: 46.55%, Precision: 44.36%, Recall: 46.55%, F1: 44.58%,loss_train:1.5150056846261535,loss_val:1.533308357556497,weight_decay:1e-05
# Early stopping at epoch 409
# Learning Rate: 0.0001, Hidden Sizes: 8, None, None, Batch Size: 32, Training Accuracy: 64.24%, Validation Accuracy: 62.73%, Precision: 62.27%, Recall: 62.73%, F1: 62.29%,loss_train:1.0898239327679637,loss_val:1.1338841416737862,weight_decay:1e-05
# Early stopping at epoch 376
# Learning Rate: 0.0001, Hidden Sizes: 8, None, None, Batch Size: 64, Training Accuracy: 62.62%, Validation Accuracy: 61.62%, Precision: 60.79%, Recall: 61.62%, F1: 60.89%,loss_train:1.15894959149116,loss_val:1.1974612939798455,weight_decay:1e-05
# Early stopping at epoch 406
# Learning Rate: 0.0001, Hidden Sizes: 8, None, None, Batch Size: 128, Training Accuracy: 62.73%, Validation Accuracy: 60.86%, Precision: 60.09%, Recall: 60.86%, F1: 60.18%,loss_train:1.1393130306165733,loss_val:1.186500297397723,weight_decay:1e-05
# Early stopping at epoch 488
# Learning Rate: 0.0001, Hidden Sizes: 16, None, None, Batch Size: 32, Training Accuracy: 77.58%, Validation Accuracy: 75.17%, Precision: 74.99%, Recall: 75.17%, F1: 75.01%,loss_train:0.7400353809326834,loss_val:0.8088062484607346,weight_decay:1e-05
# Early stopping at epoch 451
# Learning Rate: 0.0001, Hidden Sizes: 16, None, None, Batch Size: 64, Training Accuracy: 77.64%, Validation Accuracy: 74.70%, Precision: 74.47%, Recall: 74.70%, F1: 74.51%,loss_train:0.7374812799514658,loss_val:0.8068951529222219,weight_decay:1e-05
# Early stopping at epoch 484
# Learning Rate: 0.0001, Hidden Sizes: 16, None, None, Batch Size: 128, Training Accuracy: 78.35%, Validation Accuracy: 75.38%, Precision: 75.25%, Recall: 75.38%, F1: 75.24%,loss_train:0.7145053941835658,loss_val:0.7819945482738168,weight_decay:1e-05
# Early stopping at epoch 480
# Learning Rate: 0.0001, Hidden Sizes: 32, None, None, Batch Size: 32, Training Accuracy: 87.41%, Validation Accuracy: 84.87%, Precision: 84.86%, Recall: 84.87%, F1: 84.84%,loss_train:0.44235510249328314,loss_val:0.5156125293019144,weight_decay:1e-05
# Early stopping at epoch 506
# Learning Rate: 0.0001, Hidden Sizes: 32, None, None, Batch Size: 64, Training Accuracy: 86.56%, Validation Accuracy: 84.10%, Precision: 84.08%, Recall: 84.10%, F1: 84.06%,loss_train:0.4646999198137792,loss_val:0.5341155469560854,weight_decay:1e-05
# Early stopping at epoch 486
# Learning Rate: 0.0001, Hidden Sizes: 32, None, None, Batch Size: 128, Training Accuracy: 86.49%, Validation Accuracy: 83.94%, Precision: 83.91%, Recall: 83.94%, F1: 83.90%,loss_train:0.46940520634571076,loss_val:0.5355479156569801,weight_decay:1e-05
# Early stopping at epoch 507
# Learning Rate: 0.0001, Hidden Sizes: 64, None, None, Batch Size: 32, Training Accuracy: 91.34%, Validation Accuracy: 88.82%, Precision: 88.79%, Recall: 88.82%, F1: 88.79%,loss_train:0.3255009450271906,loss_val:0.39324160727371626,weight_decay:1e-05
# Early stopping at epoch 524
# Learning Rate: 0.0001, Hidden Sizes: 64, None, None, Batch Size: 64, Training Accuracy: 91.38%, Validation Accuracy: 88.70%, Precision: 88.70%, Recall: 88.70%, F1: 88.69%,loss_train:0.3247760417032489,loss_val:0.40075713023250936,weight_decay:1e-05
# Early stopping at epoch 496
# Learning Rate: 0.0001, Hidden Sizes: 64, None, None, Batch Size: 128, Training Accuracy: 90.80%, Validation Accuracy: 87.90%, Precision: 87.90%, Recall: 87.90%, F1: 87.89%,loss_train:0.34022223687704817,loss_val:0.408225714778008,weight_decay:1e-05
# Early stopping at epoch 151
# Learning Rate: 0.0001, Hidden Sizes: 2, None, None, Batch Size: 32, Training Accuracy: 23.67%, Validation Accuracy: 23.33%, Precision: 11.18%, Recall: 23.33%, F1: 13.79%,loss_train:1.9778772617535538,loss_val:1.985347799551806,weight_decay:0.0001
# Early stopping at epoch 192
# Learning Rate: 0.0001, Hidden Sizes: 2, None, None, Batch Size: 64, Training Accuracy: 23.82%, Validation Accuracy: 23.28%, Precision: 9.55%, Recall: 23.28%, F1: 12.79%,loss_train:1.9781321045526024,loss_val:1.9890065387415465,weight_decay:0.0001
# Early stopping at epoch 222
# Learning Rate: 0.0001, Hidden Sizes: 2, None, None, Batch Size: 128, Training Accuracy: 18.59%, Validation Accuracy: 18.55%, Precision: 4.20%, Recall: 18.55%, F1: 6.82%,loss_train:2.0477728810957814,loss_val:2.0579182373756724,weight_decay:0.0001
# Early stopping at epoch 242
# Learning Rate: 0.0001, Hidden Sizes: 4, None, None, Batch Size: 32, Training Accuracy: 46.26%, Validation Accuracy: 45.19%, Precision: 41.72%, Recall: 45.19%, F1: 41.70%,loss_train:1.559207066210846,loss_val:1.5849829171439602,weight_decay:0.0001
# Early stopping at epoch 199
# Learning Rate: 0.0001, Hidden Sizes: 4, None, None, Batch Size: 64, Training Accuracy: 43.16%, Validation Accuracy: 42.63%, Precision: 36.89%, Recall: 42.63%, F1: 38.22%,loss_train:1.6213096126053623,loss_val:1.641954966481652,weight_decay:0.0001
# Early stopping at epoch 220
# Learning Rate: 0.0001, Hidden Sizes: 4, None, None, Batch Size: 128, Training Accuracy: 45.70%, Validation Accuracy: 45.18%, Precision: 42.60%, Recall: 45.18%, F1: 42.87%,loss_train:1.5774905189186919,loss_val:1.595453565775825,weight_decay:0.0001
# Early stopping at epoch 283
# Learning Rate: 0.0001, Hidden Sizes: 8, None, None, Batch Size: 32, Training Accuracy: 61.87%, Validation Accuracy: 60.64%, Precision: 60.15%, Recall: 60.64%, F1: 60.14%,loss_train:1.2478300427465996,loss_val:1.2759428366986096,weight_decay:0.0001
# Early stopping at epoch 375
# Learning Rate: 0.0001, Hidden Sizes: 8, None, None, Batch Size: 64, Training Accuracy: 61.62%, Validation Accuracy: 59.99%, Precision: 59.20%, Recall: 59.99%, F1: 59.18%,loss_train:1.2409783911224568,loss_val:1.2782937077783014,weight_decay:0.0001
# Early stopping at epoch 282
# Learning Rate: 0.0001, Hidden Sizes: 8, None, None, Batch Size: 128, Training Accuracy: 60.70%, Validation Accuracy: 59.23%, Precision: 58.36%, Recall: 59.23%, F1: 58.38%,loss_train:1.2622179643320146,loss_val:1.300148057371946,weight_decay:0.0001
# Early stopping at epoch 312
# Learning Rate: 0.0001, Hidden Sizes: 16, None, None, Batch Size: 32, Training Accuracy: 74.71%, Validation Accuracy: 72.74%, Precision: 72.54%, Recall: 72.74%, F1: 72.59%,loss_train:0.9208254955931575,loss_val:0.9717450529929583,weight_decay:0.0001
# Early stopping at epoch 329
# Learning Rate: 0.0001, Hidden Sizes: 16, None, None, Batch Size: 64, Training Accuracy: 75.35%, Validation Accuracy: 73.05%, Precision: 72.75%, Recall: 73.05%, F1: 72.81%,loss_train:0.8944082218342781,loss_val:0.9514819104934118,weight_decay:0.0001
# Early stopping at epoch 346
# Learning Rate: 0.0001, Hidden Sizes: 16, None, None, Batch Size: 128, Training Accuracy: 75.95%, Validation Accuracy: 73.28%, Precision: 72.96%, Recall: 73.28%, F1: 73.00%,loss_train:0.8814273143351244,loss_val:0.935255550422101,weight_decay:0.0001
# Early stopping at epoch 347
# Learning Rate: 0.0001, Hidden Sizes: 32, None, None, Batch Size: 32, Training Accuracy: 84.00%, Validation Accuracy: 81.38%, Precision: 81.29%, Recall: 81.38%, F1: 81.31%,loss_train:0.670307573816023,loss_val:0.7377275011134437,weight_decay:0.0001
# Early stopping at epoch 362
# Learning Rate: 0.0001, Hidden Sizes: 32, None, None, Batch Size: 64, Training Accuracy: 84.89%, Validation Accuracy: 82.71%, Precision: 82.70%, Recall: 82.71%, F1: 82.66%,loss_train:0.6493524276012123,loss_val:0.7088570903624158,weight_decay:0.0001
# Early stopping at epoch 341
# Learning Rate: 0.0001, Hidden Sizes: 32, None, None, Batch Size: 128, Training Accuracy: 84.80%, Validation Accuracy: 82.60%, Precision: 82.52%, Recall: 82.60%, F1: 82.52%,loss_train:0.6539756828222835,loss_val:0.7114929805361164,weight_decay:0.0001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-180acce0cbdd> in <cell line: 22>()
#      27                 for batch_size in param_grid['batch_size']:
#      28                     for epochs in param_grid['epochs']:
# ---> 29                         train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
#      30                             hidden_size_layer1,
#      31                             hidden_size_layer2,
#
# <ipython-input-49-a4e44cc50da0> in evaluate_model(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs, weight_decay, patience, min_delta)
#      18             batch_x = x_train[i * batch_size:(i + 1) * batch_size]
#      19             batch_y = y_train_one_hot[i * batch_size:(i + 1) * batch_size]
# ---> 20             model.train(batch_x, batch_y, 1)
#      21
#      22         # Đánh giá độ chính xác và loss trên tập validation
#
# <ipython-input-48-84128e8f0d89> in train(self, X, y, epochs)
#      64         for epoch in range(epochs):
#      65             self.forward(X)
# ---> 66             self.backward(X, y)
#      67
#      68     def evaluate(self, X, y):
#
# <ipython-input-48-84128e8f0d89> in backward(self, X, y)
#      54         for i in reversed(range(len(self.layers))):
#      55             if i == 0:
# ---> 56                 self.layers[i] -= (X.T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]) * self.learning_rate
#      57             else:
#      58                 self.layers[i] -= (self.A_prev[i - 1].T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]) * self.learning_rate
#
# KeyboardInterrupt:

# %% [markdown]
# # Khi tăng weight_decay accuracy trên tập valid giảm, thử giữ nguyên learning rate,weight decay và tăng số lượng notron

# %%
param_grid = {
    'learning_rate': [0.0001],
    'hidden_size_layer1': [2,4,8,16,32,64,128,256,512],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32, 64, 128],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 281
# Learning Rate: 0.0001, Hidden Sizes: 2, None, None, Batch Size: 32, Training Accuracy: 29.30%, Validation Accuracy: 28.18%, Precision: 16.17%, Recall: 28.18%, F1: 19.86%,loss_train:1.9063470523734614,loss_val:1.9220539985030727,weight_decay:1e-05
# Early stopping at epoch 221
# Learning Rate: 0.0001, Hidden Sizes: 2, None, None, Batch Size: 64, Training Accuracy: 27.98%, Validation Accuracy: 27.44%, Precision: 13.78%, Recall: 27.44%, F1: 18.23%,loss_train:1.944454749258499,loss_val:1.9577160999229481,weight_decay:1e-05
# Early stopping at epoch 215
# Learning Rate: 0.0001, Hidden Sizes: 2, None, None, Batch Size: 128, Training Accuracy: 29.74%, Validation Accuracy: 28.72%, Precision: 14.24%, Recall: 28.72%, F1: 18.51%,loss_train:1.9081515500024786,loss_val:1.9221962488918227,weight_decay:1e-05
# Early stopping at epoch 310
# Learning Rate: 0.0001, Hidden Sizes: 4, None, None, Batch Size: 32, Training Accuracy: 46.01%, Validation Accuracy: 44.67%, Precision: 41.91%, Recall: 44.67%, F1: 40.59%,loss_train:1.5235239627198882,loss_val:1.5469975764501374,weight_decay:1e-05
# Early stopping at epoch 309
# Learning Rate: 0.0001, Hidden Sizes: 4, None, None, Batch Size: 64, Training Accuracy: 48.86%, Validation Accuracy: 47.67%, Precision: 43.57%, Recall: 47.67%, F1: 44.16%,loss_train:1.4860045065113974,loss_val:1.5127020780901161,weight_decay:1e-05
# Early stopping at epoch 344
# Learning Rate: 0.0001, Hidden Sizes: 4, None, None, Batch Size: 128, Training Accuracy: 48.44%, Validation Accuracy: 47.31%, Precision: 44.66%, Recall: 47.31%, F1: 44.07%,loss_train:1.4840744663543886,loss_val:1.5172039410467189,weight_decay:1e-05
# Early stopping at epoch 439
# Learning Rate: 0.0001, Hidden Sizes: 8, None, None, Batch Size: 32, Training Accuracy: 63.13%, Validation Accuracy: 61.73%, Precision: 60.75%, Recall: 61.73%, F1: 60.92%,loss_train:1.1323252151562913,loss_val:1.1709907655061313,weight_decay:1e-05
# Early stopping at epoch 421
# Learning Rate: 0.0001, Hidden Sizes: 8, None, None, Batch Size: 64, Training Accuracy: 65.00%, Validation Accuracy: 63.12%, Precision: 62.45%, Recall: 63.12%, F1: 62.35%,loss_train:1.0979610949308605,loss_val:1.1555091531700308,weight_decay:1e-05
# Early stopping at epoch 492
# Learning Rate: 0.0001, Hidden Sizes: 8, None, None, Batch Size: 128, Training Accuracy: 61.99%, Validation Accuracy: 60.58%, Precision: 59.85%, Recall: 60.58%, F1: 59.79%,loss_train:1.1471990299115478,loss_val:1.1927850527429373,weight_decay:1e-05
# Early stopping at epoch 547
# Learning Rate: 0.0001, Hidden Sizes: 16, None, None, Batch Size: 32, Training Accuracy: 78.77%, Validation Accuracy: 76.06%, Precision: 75.96%, Recall: 76.06%, F1: 75.96%,loss_train:0.7076606538095763,loss_val:0.779313693706076,weight_decay:1e-05
# Early stopping at epoch 487
# Learning Rate: 0.0001, Hidden Sizes: 16, None, None, Batch Size: 64, Training Accuracy: 77.98%, Validation Accuracy: 75.72%, Precision: 75.62%, Recall: 75.72%, F1: 75.60%,loss_train:0.7220531800039726,loss_val:0.7987704159715646,weight_decay:1e-05
# Early stopping at epoch 477
# Learning Rate: 0.0001, Hidden Sizes: 16, None, None, Batch Size: 128, Training Accuracy: 76.88%, Validation Accuracy: 75.01%, Precision: 74.79%, Recall: 75.01%, F1: 74.83%,loss_train:0.7504963477876535,loss_val:0.8192959568754378,weight_decay:1e-05
# Early stopping at epoch 481
# Learning Rate: 0.0001, Hidden Sizes: 32, None, None, Batch Size: 32, Training Accuracy: 86.14%, Validation Accuracy: 83.12%, Precision: 83.11%, Recall: 83.12%, F1: 83.08%,loss_train:0.48607403862216336,loss_val:0.5691281035411712,weight_decay:1e-05
# Early stopping at epoch 513
# Learning Rate: 0.0001, Hidden Sizes: 32, None, None, Batch Size: 64, Training Accuracy: 86.56%, Validation Accuracy: 84.08%, Precision: 84.07%, Recall: 84.08%, F1: 84.04%,loss_train:0.46864869692979055,loss_val:0.5422680562918241,weight_decay:1e-05
# Early stopping at epoch 496
# Learning Rate: 0.0001, Hidden Sizes: 32, None, None, Batch Size: 128, Training Accuracy: 86.71%, Validation Accuracy: 84.00%, Precision: 84.01%, Recall: 84.00%, F1: 83.97%,loss_train:0.4639512864459323,loss_val:0.538160199952657,weight_decay:1e-05
# Early stopping at epoch 514
# Learning Rate: 0.0001, Hidden Sizes: 64, None, None, Batch Size: 32, Training Accuracy: 91.60%, Validation Accuracy: 88.12%, Precision: 88.12%, Recall: 88.12%, F1: 88.10%,loss_train:0.32290046088685787,loss_val:0.4062427247074719,weight_decay:1e-05
# Early stopping at epoch 488
# Learning Rate: 0.0001, Hidden Sizes: 64, None, None, Batch Size: 64, Training Accuracy: 91.03%, Validation Accuracy: 88.18%, Precision: 88.19%, Recall: 88.18%, F1: 88.17%,loss_train:0.3348291696865746,loss_val:0.41292859825064776,weight_decay:1e-05
# Early stopping at epoch 491
# Learning Rate: 0.0001, Hidden Sizes: 64, None, None, Batch Size: 128, Training Accuracy: 91.09%, Validation Accuracy: 87.95%, Precision: 87.94%, Recall: 87.95%, F1: 87.93%,loss_train:0.3368828036055322,loss_val:0.41580787075278114,weight_decay:1e-05
# Early stopping at epoch 542
# Learning Rate: 0.0001, Hidden Sizes: 128, None, None, Batch Size: 32, Training Accuracy: 93.50%, Validation Accuracy: 90.04%, Precision: 90.05%, Recall: 90.04%, F1: 90.03%,loss_train:0.25899993180104236,loss_val:0.3473113418031961,weight_decay:1e-05
# Early stopping at epoch 527
# Learning Rate: 0.0001, Hidden Sizes: 128, None, None, Batch Size: 64, Training Accuracy: 93.32%, Validation Accuracy: 90.22%, Precision: 90.22%, Recall: 90.22%, F1: 90.21%,loss_train:0.26494095703481285,loss_val:0.3459356427421249,weight_decay:1e-05
# Early stopping at epoch 527
# Learning Rate: 0.0001, Hidden Sizes: 128, None, None, Batch Size: 128, Training Accuracy: 93.53%, Validation Accuracy: 90.51%, Precision: 90.51%, Recall: 90.51%, F1: 90.50%,loss_train:0.2559836676805505,loss_val:0.3364117517922148,weight_decay:1e-05
# Early stopping at epoch 569
# Learning Rate: 0.0001, Hidden Sizes: 256, None, None, Batch Size: 32, Training Accuracy: 94.12%, Validation Accuracy: 90.85%, Precision: 90.85%, Recall: 90.85%, F1: 90.84%,loss_train:0.2410501715186424,loss_val:0.32888686051599325,weight_decay:1e-05
# Early stopping at epoch 577
# Learning Rate: 0.0001, Hidden Sizes: 256, None, None, Batch Size: 64, Training Accuracy: 94.20%, Validation Accuracy: 91.19%, Precision: 91.20%, Recall: 91.19%, F1: 91.19%,loss_train:0.24018583205690475,loss_val:0.3254794445832809,weight_decay:1e-05
# Early stopping at epoch 585
# Learning Rate: 0.0001, Hidden Sizes: 256, None, None, Batch Size: 128, Training Accuracy: 94.17%, Validation Accuracy: 90.63%, Precision: 90.64%, Recall: 90.63%, F1: 90.62%,loss_train:0.24417254971556715,loss_val:0.3313019148541311,weight_decay:1e-05
# Early stopping at epoch 603
# Learning Rate: 0.0001, Hidden Sizes: 512, None, None, Batch Size: 32, Training Accuracy: 94.22%, Validation Accuracy: 90.85%, Precision: 90.86%, Recall: 90.85%, F1: 90.84%,loss_train:0.24074509333945887,loss_val:0.3311115647068964,weight_decay:1e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-3993aa6a740d> in <cell line: 12>()
#      17                 for batch_size in param_grid['batch_size']:
#      18                     for epochs in param_grid['epochs']:
# ---> 19                         train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
#      20                             hidden_size_layer1,
#      21                             hidden_size_layer2,
#
# <ipython-input-21-a4e44cc50da0> in evaluate_model(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs, weight_decay, patience, min_delta)
#      18             batch_x = x_train[i * batch_size:(i + 1) * batch_size]
#      19             batch_y = y_train_one_hot[i * batch_size:(i + 1) * batch_size]
# ---> 20             model.train(batch_x, batch_y, 1)
#      21
#      22         # Đánh giá độ chính xác và loss trên tập validation
#
# <ipython-input-20-84128e8f0d89> in train(self, X, y, epochs)
#      64         for epoch in range(epochs):
#      65             self.forward(X)
# ---> 66             self.backward(X, y)
#      67
#      68     def evaluate(self, X, y):
#
# <ipython-input-20-84128e8f0d89> in backward(self, X, y)
#      58                 self.layers[i] -= (self.A_prev[i - 1].T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]) * self.learning_rate
#      59
# ---> 60             if i > 0:
#      61                 hidden_delta = hidden_delta.dot(self.layers[i].T) * self.sigmoid_derivative(self.A_prev[i - 1])
#      62
#
# KeyboardInterrupt:

# %% [markdown]
# # Thử tăng learning rate từ 0.0001 lên 0.001 để mô hình hội tụ nhanh hơn

# %%
param_grid = {
    'learning_rate': [0.001],
    'hidden_size_layer1': [2,4,8,16,32,64,128,256,512],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32, 64, 128],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 64
# Learning Rate: 0.001, Hidden Sizes: 2, None, None, Batch Size: 32, Training Accuracy: 29.37%, Validation Accuracy: 28.16%, Precision: 14.15%, Recall: 28.16%, F1: 18.79%,loss_train:1.894641505929142,loss_val:1.9256968943040975,weight_decay:1e-05
# Early stopping at epoch 68
# Learning Rate: 0.001, Hidden Sizes: 2, None, None, Batch Size: 64, Training Accuracy: 28.23%, Validation Accuracy: 27.47%, Precision: 11.91%, Recall: 27.47%, F1: 16.33%,loss_train:1.8886314363252434,loss_val:1.9163440099064262,weight_decay:1e-05
# Early stopping at epoch 258
# Learning Rate: 0.001, Hidden Sizes: 2, None, None, Batch Size: 128, Training Accuracy: 29.48%, Validation Accuracy: 28.53%, Precision: 20.49%, Recall: 28.53%, F1: 22.70%,loss_train:1.8561946536400964,loss_val:1.8858453495021694,weight_decay:1e-05
# Early stopping at epoch 119
# Learning Rate: 0.001, Hidden Sizes: 4, None, None, Batch Size: 32, Training Accuracy: 52.46%, Validation Accuracy: 51.01%, Precision: 48.89%, Recall: 51.01%, F1: 49.12%,loss_train:1.389739810129467,loss_val:1.442372885013379,weight_decay:1e-05
# Early stopping at epoch 99
# Learning Rate: 0.001, Hidden Sizes: 4, None, None, Batch Size: 64, Training Accuracy: 49.05%, Validation Accuracy: 47.38%, Precision: 46.58%, Recall: 47.38%, F1: 44.55%,loss_train:1.4534977244314837,loss_val:1.4951287513675144,weight_decay:1e-05
# Early stopping at epoch 42
# Learning Rate: 0.001, Hidden Sizes: 4, None, None, Batch Size: 128, Training Accuracy: 46.33%, Validation Accuracy: 44.88%, Precision: 41.75%, Recall: 44.88%, F1: 40.70%,loss_train:1.5298530952689027,loss_val:1.5785229773881795,weight_decay:1e-05
# Early stopping at epoch 90
# Learning Rate: 0.001, Hidden Sizes: 8, None, None, Batch Size: 32, Training Accuracy: 63.72%, Validation Accuracy: 60.92%, Precision: 59.71%, Recall: 60.92%, F1: 59.90%,loss_train:1.095525576469084,loss_val:1.1686084561708068,weight_decay:1e-05
# Early stopping at epoch 120
# Learning Rate: 0.001, Hidden Sizes: 8, None, None, Batch Size: 64, Training Accuracy: 66.19%, Validation Accuracy: 64.25%, Precision: 62.69%, Recall: 64.25%, F1: 63.02%,loss_train:1.0174060818174766,loss_val:1.0816471999574482,weight_decay:1e-05
# Early stopping at epoch 114
# Learning Rate: 0.001, Hidden Sizes: 8, None, None, Batch Size: 128, Training Accuracy: 62.89%, Validation Accuracy: 60.47%, Precision: 58.92%, Recall: 60.47%, F1: 59.25%,loss_train:1.0874938427564833,loss_val:1.153628350078396,weight_decay:1e-05
# Early stopping at epoch 96
# Learning Rate: 0.001, Hidden Sizes: 16, None, None, Batch Size: 32, Training Accuracy: 80.80%, Validation Accuracy: 77.21%, Precision: 77.16%, Recall: 77.21%, F1: 77.09%,loss_train:0.6426139096152004,loss_val:0.7330487913171617,weight_decay:1e-05
# Early stopping at epoch 99
# Learning Rate: 0.001, Hidden Sizes: 16, None, None, Batch Size: 64, Training Accuracy: 79.15%, Validation Accuracy: 75.38%, Precision: 75.54%, Recall: 75.38%, F1: 75.35%,loss_train:0.6758572841287571,loss_val:0.7736808049080232,weight_decay:1e-05
# Early stopping at epoch 108
# Learning Rate: 0.001, Hidden Sizes: 16, None, None, Batch Size: 128, Training Accuracy: 80.97%, Validation Accuracy: 77.62%, Precision: 77.48%, Recall: 77.62%, F1: 77.51%,loss_train:0.6339898501804531,loss_val:0.7209975968580913,weight_decay:1e-05
# Early stopping at epoch 104
# Learning Rate: 0.001, Hidden Sizes: 32, None, None, Batch Size: 32, Training Accuracy: 89.46%, Validation Accuracy: 85.44%, Precision: 85.46%, Recall: 85.44%, F1: 85.42%,loss_train:0.3748877911486757,loss_val:0.49158429104228707,weight_decay:1e-05
# Early stopping at epoch 107
# Learning Rate: 0.001, Hidden Sizes: 32, None, None, Batch Size: 64, Training Accuracy: 90.04%, Validation Accuracy: 85.72%, Precision: 85.78%, Recall: 85.72%, F1: 85.70%,loss_train:0.35971061393210735,loss_val:0.4832347682048595,weight_decay:1e-05
# Early stopping at epoch 95
# Learning Rate: 0.001, Hidden Sizes: 32, None, None, Batch Size: 128, Training Accuracy: 89.85%, Validation Accuracy: 85.78%, Precision: 85.86%, Recall: 85.78%, F1: 85.77%,loss_train:0.36981242465257563,loss_val:0.48596517948621426,weight_decay:1e-05
# Early stopping at epoch 95
# Learning Rate: 0.001, Hidden Sizes: 64, None, None, Batch Size: 32, Training Accuracy: 93.46%, Validation Accuracy: 88.62%, Precision: 88.63%, Recall: 88.62%, F1: 88.61%,loss_train:0.25624697949356945,loss_val:0.38752415082085456,weight_decay:1e-05
# Early stopping at epoch 97
# Learning Rate: 0.001, Hidden Sizes: 64, None, None, Batch Size: 64, Training Accuracy: 94.04%, Validation Accuracy: 89.28%, Precision: 89.32%, Recall: 89.28%, F1: 89.28%,loss_train:0.2402845177239767,loss_val:0.3612717210747739,weight_decay:1e-05
# Early stopping at epoch 97
# Learning Rate: 0.001, Hidden Sizes: 64, None, None, Batch Size: 128, Training Accuracy: 94.17%, Validation Accuracy: 89.63%, Precision: 89.64%, Recall: 89.63%, F1: 89.62%,loss_train:0.239048912450191,loss_val:0.3636933459068336,weight_decay:1e-05
# Early stopping at epoch 103
# Learning Rate: 0.001, Hidden Sizes: 128, None, None, Batch Size: 32, Training Accuracy: 96.40%, Validation Accuracy: 91.33%, Precision: 91.33%, Recall: 91.33%, F1: 91.31%,loss_train:0.17401718154215456,loss_val:0.3071325432938049,weight_decay:1e-05
# Early stopping at epoch 107
# Learning Rate: 0.001, Hidden Sizes: 128, None, None, Batch Size: 64, Training Accuracy: 96.75%, Validation Accuracy: 91.86%, Precision: 91.85%, Recall: 91.86%, F1: 91.85%,loss_train:0.16709404243805742,loss_val:0.29608026193810205,weight_decay:1e-05
# Early stopping at epoch 109
# Learning Rate: 0.001, Hidden Sizes: 128, None, None, Batch Size: 128, Training Accuracy: 96.61%, Validation Accuracy: 91.84%, Precision: 91.85%, Recall: 91.84%, F1: 91.84%,loss_train:0.1670018530387404,loss_val:0.302272515475029,weight_decay:1e-05
# Early stopping at epoch 113
# Learning Rate: 0.001, Hidden Sizes: 256, None, None, Batch Size: 32, Training Accuracy: 97.50%, Validation Accuracy: 92.50%, Precision: 92.50%, Recall: 92.50%, F1: 92.49%,loss_train:0.14712859533661538,loss_val:0.2777863637284085,weight_decay:1e-05
# Early stopping at epoch 117
# Learning Rate: 0.001, Hidden Sizes: 256, None, None, Batch Size: 64, Training Accuracy: 97.79%, Validation Accuracy: 92.59%, Precision: 92.58%, Recall: 92.59%, F1: 92.58%,loss_train:0.1397211101620647,loss_val:0.27672327504477723,weight_decay:1e-05
# Early stopping at epoch 117
# Learning Rate: 0.001, Hidden Sizes: 256, None, None, Batch Size: 128, Training Accuracy: 97.70%, Validation Accuracy: 92.45%, Precision: 92.45%, Recall: 92.45%, F1: 92.44%,loss_train:0.14184541031909775,loss_val:0.28060234263638456,weight_decay:1e-05
# Early stopping at epoch 120
# Learning Rate: 0.001, Hidden Sizes: 512, None, None, Batch Size: 32, Training Accuracy: 97.91%, Validation Accuracy: 92.62%, Precision: 92.62%, Recall: 92.62%, F1: 92.61%,loss_train:0.1393089482947982,loss_val:0.27882482938161995,weight_decay:1e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-91aa51fca002> in <cell line: 12>()
#      17                 for batch_size in param_grid['batch_size']:
#      18                     for epochs in param_grid['epochs']:
# ---> 19                         train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
#      20                             hidden_size_layer1,
#      21                             hidden_size_layer2,
#
# <ipython-input-43-a4e44cc50da0> in evaluate_model(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs, weight_decay, patience, min_delta)
#      18             batch_x = x_train[i * batch_size:(i + 1) * batch_size]
#      19             batch_y = y_train_one_hot[i * batch_size:(i + 1) * batch_size]
# ---> 20             model.train(batch_x, batch_y, 1)
#      21
#      22         # Đánh giá độ chính xác và loss trên tập validation
#
# <ipython-input-42-84128e8f0d89> in train(self, X, y, epochs)
#      64         for epoch in range(epochs):
#      65             self.forward(X)
# ---> 66             self.backward(X, y)
#      67
#      68     def evaluate(self, X, y):
#
# <ipython-input-42-84128e8f0d89> in backward(self, X, y)
#      54         for i in reversed(range(len(self.layers))):
#      55             if i == 0:
# ---> 56                 self.layers[i] -= (X.T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]) * self.learning_rate
#      57             else:
#      58                 self.layers[i] -= (self.A_prev[i - 1].T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]) * self.learning_rate
#
# KeyboardInterrupt:

# %% [markdown]
# # Mô hình đang có hiện tượng overfiting , thử giảm learning rate xuống

# %%
param_grid = {
    'learning_rate': [0.0001],
    'hidden_size_layer1': [512],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32, 64, 128],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 602
# Learning Rate: 0.0001, Hidden Sizes: 512, None, None, Batch Size: 32, Training Accuracy: 94.33%, Validation Accuracy: 91.05%, Precision: 91.05%, Recall: 91.05%, F1: 91.04%,loss_train:0.2383419826388497,loss_val:0.3198068640810266,weight_decay:1e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-b4f28440dadd> in <cell line: 12>()
#      17                 for batch_size in param_grid['batch_size']:
#      18                     for epochs in param_grid['epochs']:
# ---> 19                         train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
#      20                             hidden_size_layer1,
#      21                             hidden_size_layer2,
#
# <ipython-input-21-a4e44cc50da0> in evaluate_model(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs, weight_decay, patience, min_delta)
#      21
#      22         # Đánh giá độ chính xác và loss trên tập validation
# ---> 23         val_accuracy, val_loss = model.evaluate(x_val, y_val_one_hot)
#      24
#      25         # Kiểm tra điều kiện early stopping
#
# <ipython-input-20-84128e8f0d89> in evaluate(self, X, y)
#      67
#      68     def evaluate(self, X, y):
# ---> 69         output = self.forward(X)
#      70         predictions = np.argmax(output, axis=1)
#      71         true_labels = np.argmax(y, axis=1)
#
# <ipython-input-20-84128e8f0d89> in forward(self, X)
#      38
#      39         for W in self.layers:
# ---> 40             self.Z = np.dot(self.A, W)
#      41             self.A = self.sigmoid(self.Z)
#      42             self.A_prev.append(self.A)
#
# KeyboardInterrupt:

# %% [markdown]
# # thử nghiệm với 2 lớp ẩn

# %%
param_grid = {
    'learning_rate': [0.001],
    'hidden_size_layer1': [128,256,512],
    'hidden_size_layer2': [128,256,512],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    'batch_size': [32, 64, 128],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 65
# Learning Rate: 0.001, Hidden Sizes: 128, 128, None, Batch Size: 32, Training Accuracy: 96.29%, Validation Accuracy: 91.44%, Precision: 91.48%, Recall: 91.44%, F1: 91.44%,loss_train:0.15964548200099896,loss_val:0.31444976954066,weight_decay:1e-05
# Early stopping at epoch 64
# Learning Rate: 0.001, Hidden Sizes: 128, 128, None, Batch Size: 64, Training Accuracy: 96.06%, Validation Accuracy: 90.96%, Precision: 91.04%, Recall: 90.96%, F1: 90.97%,loss_train:0.16548948814725786,loss_val:0.3179897887344657,weight_decay:1e-05
# Early stopping at epoch 63
# Learning Rate: 0.001, Hidden Sizes: 128, 128, None, Batch Size: 128, Training Accuracy: 95.69%, Validation Accuracy: 90.92%, Precision: 91.09%, Recall: 90.92%, F1: 90.94%,loss_train:0.1697350453595703,loss_val:0.31997574614252006,weight_decay:1e-05
# Early stopping at epoch 67
# Learning Rate: 0.001, Hidden Sizes: 256, 128, None, Batch Size: 32, Training Accuracy: 96.75%, Validation Accuracy: 91.65%, Precision: 91.72%, Recall: 91.65%, F1: 91.65%,loss_train:0.14512252627237504,loss_val:0.3019770340898611,weight_decay:1e-05
# Early stopping at epoch 74
# Learning Rate: 0.001, Hidden Sizes: 256, 128, None, Batch Size: 64, Training Accuracy: 97.09%, Validation Accuracy: 91.72%, Precision: 91.79%, Recall: 91.72%, F1: 91.71%,loss_train:0.13674599282103903,loss_val:0.2963043087467939,weight_decay:1e-05
# Early stopping at epoch 74
# Learning Rate: 0.001, Hidden Sizes: 256, 128, None, Batch Size: 128, Training Accuracy: 96.81%, Validation Accuracy: 91.83%, Precision: 91.94%, Recall: 91.83%, F1: 91.83%,loss_train:0.1424763122928429,loss_val:0.2976932464070667,weight_decay:1e-05
# Early stopping at epoch 81
# Learning Rate: 0.001, Hidden Sizes: 512, 128, None, Batch Size: 32, Training Accuracy: 96.96%, Validation Accuracy: 92.21%, Precision: 92.35%, Recall: 92.21%, F1: 92.22%,loss_train:0.1427629513782927,loss_val:0.2924363322401459,weight_decay:1e-05
# Early stopping at epoch 75
# Learning Rate: 0.001, Hidden Sizes: 512, 128, None, Batch Size: 64, Training Accuracy: 96.14%, Validation Accuracy: 92.08%, Precision: 92.22%, Recall: 92.08%, F1: 92.09%,loss_train:0.16549507650139683,loss_val:0.2924238450594823,weight_decay:1e-05
# Early stopping at epoch 121
# Learning Rate: 0.001, Hidden Sizes: 512, 128, None, Batch Size: 128, Training Accuracy: 98.34%, Validation Accuracy: 92.72%, Precision: 92.80%, Recall: 92.72%, F1: 92.70%,loss_train:0.11142366707945972,loss_val:0.3019919198452347,weight_decay:1e-05
# Early stopping at epoch 64
# Learning Rate: 0.001, Hidden Sizes: 128, 256, None, Batch Size: 32, Training Accuracy: 96.27%, Validation Accuracy: 91.41%, Precision: 91.47%, Recall: 91.41%, F1: 91.41%,loss_train:0.15677890769441882,loss_val:0.31185124703504713,weight_decay:1e-05
# Early stopping at epoch 63
# Learning Rate: 0.001, Hidden Sizes: 128, 256, None, Batch Size: 64, Training Accuracy: 96.09%, Validation Accuracy: 91.03%, Precision: 91.03%, Recall: 91.03%, F1: 91.02%,loss_train:0.16359709468821512,loss_val:0.3261647477552956,weight_decay:1e-05
# Early stopping at epoch 62
# Learning Rate: 0.001, Hidden Sizes: 128, 256, None, Batch Size: 128, Training Accuracy: 95.40%, Validation Accuracy: 91.04%, Precision: 91.17%, Recall: 91.04%, F1: 91.05%,loss_train:0.17926805865267262,loss_val:0.3254239722800983,weight_decay:1e-05
# Early stopping at epoch 65
# Learning Rate: 0.001, Hidden Sizes: 256, 256, None, Batch Size: 32, Training Accuracy: 96.24%, Validation Accuracy: 91.12%, Precision: 91.28%, Recall: 91.12%, F1: 91.13%,loss_train:0.15674934544934882,loss_val:0.31050587840332633,weight_decay:1e-05
# Early stopping at epoch 74
# Learning Rate: 0.001, Hidden Sizes: 256, 256, None, Batch Size: 64, Training Accuracy: 97.25%, Validation Accuracy: 91.82%, Precision: 91.86%, Recall: 91.82%, F1: 91.81%,loss_train:0.1323902682949346,loss_val:0.3011341737189542,weight_decay:1e-05
# Early stopping at epoch 9
# Learning Rate: 0.001, Hidden Sizes: 256, 256, None, Batch Size: 128, Training Accuracy: 42.92%, Validation Accuracy: 42.27%, Precision: 55.12%, Recall: 42.27%, F1: 39.53%,loss_train:1.7851161960121251,loss_val:1.8041401868874765,weight_decay:1e-05
# Early stopping at epoch 70
# Learning Rate: 0.001, Hidden Sizes: 512, 256, None, Batch Size: 32, Training Accuracy: 95.75%, Validation Accuracy: 91.28%, Precision: 91.51%, Recall: 91.28%, F1: 91.31%,loss_train:0.17477251451680698,loss_val:0.3167207198760958,weight_decay:1e-05

# %% [markdown]
# # Kết quả cao nhất là 512 128, với 128 batch thử tăng tiếp số lượng hidden layer lên

# %%
param_grid = {
    'learning_rate': [0.0005],
    'hidden_size_layer1': [512],
    'hidden_size_layer2': [128],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    'batch_size': [128],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-5ebfe43a7e4a> in <cell line: 11>()
#      16                 for batch_size in param_grid['batch_size']:
#      17                     for epochs in param_grid['epochs']:
# ---> 18                         train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
#      19                             hidden_size_layer1,
#      20                             hidden_size_layer2,
#
# <ipython-input-22-a4e44cc50da0> in evaluate_model(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs, weight_decay, patience, min_delta)
#      18             batch_x = x_train[i * batch_size:(i + 1) * batch_size]
#      19             batch_y = y_train_one_hot[i * batch_size:(i + 1) * batch_size]
# ---> 20             model.train(batch_x, batch_y, 1)
#      21
#      22         # Đánh giá độ chính xác và loss trên tập validation
#
# <ipython-input-21-84128e8f0d89> in train(self, X, y, epochs)
#      64         for epoch in range(epochs):
#      65             self.forward(X)
# ---> 66             self.backward(X, y)
#      67
#      68     def evaluate(self, X, y):
#
# <ipython-input-21-84128e8f0d89> in backward(self, X, y)
#      54         for i in reversed(range(len(self.layers))):
#      55             if i == 0:
# ---> 56                 self.layers[i] -= (X.T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]) * self.learning_rate
#      57             else:
#      58                 self.layers[i] -= (self.A_prev[i - 1].T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]) * self.learning_rate
#
# KeyboardInterrupt:

# %% [markdown]
# Thử tăng lớp hidden layer lên

# %%
param_grid = {
    'learning_rate': [0.001],
    'hidden_size_layer1': [2,4,8,16,32,64,128,256,512],
    'hidden_size_layer2': [2,4,8,16,32,64,128,256,512],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [2],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32, 64, 128],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 90
# Learning Rate: 0.001, Hidden Sizes: 2, 2, 2, Batch Size: 32, Training Accuracy: 26.36%, Validation Accuracy: 25.41%, Precision: 18.26%, Recall: 25.41%, F1: 19.20%,loss_train:1.9042748350673049,loss_val:1.9317997910942166,weight_decay:1e-05
# Early stopping at epoch 81
# Learning Rate: 0.001, Hidden Sizes: 2, 2, 2, Batch Size: 64, Training Accuracy: 27.43%, Validation Accuracy: 26.07%, Precision: 18.49%, Recall: 26.07%, F1: 20.27%,loss_train:1.8856753721163078,loss_val:1.912303861892902,weight_decay:1e-05
# Early stopping at epoch 7
# Learning Rate: 0.001, Hidden Sizes: 2, 2, 2, Batch Size: 128, Training Accuracy: 11.29%, Validation Accuracy: 11.02%, Precision: 1.21%, Recall: 11.02%, F1: 2.19%,loss_train:2.3010812309359876,loss_val:2.3014643894076405,weight_decay:1e-05
# Early stopping at epoch 6
# Learning Rate: 0.001, Hidden Sizes: 4, 2, 2, Batch Size: 32, Training Accuracy: 11.29%, Validation Accuracy: 11.02%, Precision: 1.21%, Recall: 11.02%, F1: 2.19%,loss_train:2.300985495203344,loss_val:2.3014616566432866,weight_decay:1e-05
# Early stopping at epoch 44
# Learning Rate: 0.001, Hidden Sizes: 4, 2, 2, Batch Size: 64, Training Accuracy: 27.95%, Validation Accuracy: 26.82%, Precision: 18.95%, Recall: 26.82%, F1: 20.31%,loss_train:1.7971210890854314,loss_val:1.82253243029792,weight_decay:1e-05
# Early stopping at epoch 6
# Learning Rate: 0.001, Hidden Sizes: 4, 2, 2, Batch Size: 128, Training Accuracy: 11.29%, Validation Accuracy: 11.02%, Precision: 1.21%, Recall: 11.02%, F1: 2.19%,loss_train:2.3009883639604873,loss_val:2.301442108605306,weight_decay:1e-05
# Early stopping at epoch 72
# Learning Rate: 0.001, Hidden Sizes: 8, 2, 2, Batch Size: 32, Training Accuracy: 36.57%, Validation Accuracy: 35.31%, Precision: 27.05%, Recall: 35.31%, F1: 28.94%,loss_train:1.618467001274569,loss_val:1.6848522731714373,weight_decay:1e-05
# Early stopping at epoch 76
# Learning Rate: 0.001, Hidden Sizes: 8, 2, 2, Batch Size: 64, Training Accuracy: 40.38%, Validation Accuracy: 38.51%, Precision: 33.21%, Recall: 38.51%, F1: 35.00%,loss_train:1.542655958635925,loss_val:1.6242173169040581,weight_decay:1e-05
# Early stopping at epoch 49
# Learning Rate: 0.001, Hidden Sizes: 8, 2, 2, Batch Size: 128, Training Accuracy: 37.58%, Validation Accuracy: 35.73%, Precision: 30.91%, Recall: 35.73%, F1: 32.40%,loss_train:1.5999274005608153,loss_val:1.6418205363013225,weight_decay:1e-05
# Early stopping at epoch 87
# Learning Rate: 0.001, Hidden Sizes: 16, 2, 2, Batch Size: 32, Training Accuracy: 44.85%, Validation Accuracy: 42.21%, Precision: 37.21%, Recall: 42.21%, F1: 38.22%,loss_train:1.3918091944047397,loss_val:1.504412687631462,weight_decay:1e-05
# Early stopping at epoch 79
# Learning Rate: 0.001, Hidden Sizes: 16, 2, 2, Batch Size: 64, Training Accuracy: 45.58%, Validation Accuracy: 42.89%, Precision: 37.43%, Recall: 42.89%, F1: 39.63%,loss_train:1.3976636535918108,loss_val:1.4985744069080256,weight_decay:1e-05
# Early stopping at epoch 66
# Learning Rate: 0.001, Hidden Sizes: 16, 2, 2, Batch Size: 128, Training Accuracy: 40.88%, Validation Accuracy: 39.88%, Precision: 33.22%, Recall: 39.88%, F1: 35.12%,loss_train:1.4483962577648193,loss_val:1.5257339808388026,weight_decay:1e-05
# Early stopping at epoch 105
# Learning Rate: 0.001, Hidden Sizes: 32, 2, 2, Batch Size: 32, Training Accuracy: 53.19%, Validation Accuracy: 47.98%, Precision: 44.44%, Recall: 47.98%, F1: 45.22%,loss_train:1.1914271805616392,loss_val:1.3795176237989955,weight_decay:1e-05
# Early stopping at epoch 6
# Learning Rate: 0.001, Hidden Sizes: 32, 2, 2, Batch Size: 64, Training Accuracy: 11.29%, Validation Accuracy: 11.02%, Precision: 1.21%, Recall: 11.02%, F1: 2.19%,loss_train:2.301091093235814,loss_val:2.3015492375899296,weight_decay:1e-05
# Early stopping at epoch 92
# Learning Rate: 0.001, Hidden Sizes: 32, 2, 2, Batch Size: 128, Training Accuracy: 47.93%, Validation Accuracy: 45.48%, Precision: 36.87%, Recall: 45.48%, F1: 40.18%,loss_train:1.2720927389586096,loss_val:1.3884950630106443,weight_decay:1e-05
# Early stopping at epoch 49
# Learning Rate: 0.001, Hidden Sizes: 64, 2, 2, Batch Size: 32, Training Accuracy: 34.96%, Validation Accuracy: 33.98%, Precision: 30.38%, Recall: 33.98%, F1: 31.04%,loss_train:1.5556671053793785,loss_val:1.604912945972316,weight_decay:1e-05
# Early stopping at epoch 77
# Learning Rate: 0.001, Hidden Sizes: 64, 2, 2, Batch Size: 64, Training Accuracy: 48.62%, Validation Accuracy: 45.52%, Precision: 43.83%, Recall: 45.52%, F1: 42.81%,loss_train:1.2531972047360191,loss_val:1.368106794373352,weight_decay:1e-05
# Early stopping at epoch 90
# Learning Rate: 0.001, Hidden Sizes: 64, 2, 2, Batch Size: 128, Training Accuracy: 32.52%, Validation Accuracy: 31.51%, Precision: 25.24%, Recall: 31.51%, F1: 25.19%,loss_train:1.6099154496913013,loss_val:1.6588672946796634,weight_decay:1e-05
# Early stopping at epoch 6
# Learning Rate: 0.001, Hidden Sizes: 128, 2, 2, Batch Size: 32, Training Accuracy: 11.29%, Validation Accuracy: 11.02%, Precision: 1.21%, Recall: 11.02%, F1: 2.19%,loss_train:2.3032839420359568,loss_val:2.303724463205472,weight_decay:1e-05
# Early stopping at epoch 52
# Learning Rate: 0.001, Hidden Sizes: 128, 2, 2, Batch Size: 64, Training Accuracy: 32.23%, Validation Accuracy: 30.94%, Precision: 25.03%, Recall: 30.94%, F1: 25.57%,loss_train:1.6177262436431858,loss_val:1.6513744847552962,weight_decay:1e-05
# Early stopping at epoch 56
# Learning Rate: 0.001, Hidden Sizes: 128, 2, 2, Batch Size: 128, Training Accuracy: 34.70%, Validation Accuracy: 34.01%, Precision: 28.85%, Recall: 34.01%, F1: 25.92%,loss_train:1.6086583624018274,loss_val:1.6401879770696302,weight_decay:1e-05
# Early stopping at epoch 60
# Learning Rate: 0.001, Hidden Sizes: 256, 2, 2, Batch Size: 32, Training Accuracy: 27.76%, Validation Accuracy: 27.59%, Precision: 16.35%, Recall: 27.59%, F1: 19.30%,loss_train:1.7001425120246623,loss_val:1.725434509683125,weight_decay:1e-05
# Early stopping at epoch 97
# Learning Rate: 0.001, Hidden Sizes: 256, 2, 2, Batch Size: 64, Training Accuracy: 39.25%, Validation Accuracy: 38.21%, Precision: 31.40%, Recall: 38.21%, F1: 31.97%,loss_train:1.4957436905399502,loss_val:1.5458627182825544,weight_decay:1e-05
# Early stopping at epoch 48
# Learning Rate: 0.001, Hidden Sizes: 256, 2, 2, Batch Size: 128, Training Accuracy: 34.85%, Validation Accuracy: 34.47%, Precision: 24.88%, Recall: 34.47%, F1: 26.17%,loss_train:1.5861987412784724,loss_val:1.6054861596616923,weight_decay:1e-05
# Early stopping at epoch 50
# Learning Rate: 0.001, Hidden Sizes: 512, 2, 2, Batch Size: 32, Training Accuracy: 36.61%, Validation Accuracy: 36.04%, Precision: 29.47%, Recall: 36.04%, F1: 28.57%,loss_train:1.5703561031464868,loss_val:1.601275887803307,weight_decay:1e-05
# Early stopping at epoch 48
# Learning Rate: 0.001, Hidden Sizes: 512, 2, 2, Batch Size: 64, Training Accuracy: 36.32%, Validation Accuracy: 35.64%, Precision: 28.05%, Recall: 35.64%, F1: 28.91%,loss_train:1.6372893011825524,loss_val:1.6561982418862333,weight_decay:1e-05
# Early stopping at epoch 50
# Learning Rate: 0.001, Hidden Sizes: 512, 2, 2, Batch Size: 128, Training Accuracy: 33.14%, Validation Accuracy: 32.96%, Precision: 24.63%, Recall: 32.96%, F1: 24.22%,loss_train:1.6335520247862299,loss_val:1.6532227952039944,weight_decay:1e-05
# Early stopping at epoch 70
# Learning Rate: 0.001, Hidden Sizes: 2, 4, 2, Batch Size: 32, Training Accuracy: 28.48%, Validation Accuracy: 28.43%, Precision: 21.46%, Recall: 28.43%, F1: 22.80%,loss_train:1.8171964457377066,loss_val:1.8463394271332614,weight_decay:1e-05
# Early stopping at epoch 6
# Learning Rate: 0.001, Hidden Sizes: 2, 4, 2, Batch Size: 64, Training Accuracy: 11.29%, Validation Accuracy: 11.02%, Precision: 1.21%, Recall: 11.02%, F1: 2.19%,loss_train:2.300888022204015,loss_val:2.3013444764773237,weight_decay:1e-05
# Early stopping at epoch 6
# Learning Rate: 0.001, Hidden Sizes: 2, 4, 2, Batch Size: 128, Training Accuracy: 11.29%, Validation Accuracy: 11.02%, Precision: 1.21%, Recall: 11.02%, F1: 2.19%,loss_train:2.300843945133786,loss_val:2.30127431300736,weight_decay:1e-05
# Early stopping at epoch 51
# Learning Rate: 0.001, Hidden Sizes: 4, 4, 2, Batch Size: 32, Training Accuracy: 35.06%, Validation Accuracy: 33.77%, Precision: 22.65%, Recall: 33.77%, F1: 26.19%,loss_train:1.7798300714693847,loss_val:1.813532732892406,weight_decay:1e-05
# Early stopping at epoch 64
# Learning Rate: 0.001, Hidden Sizes: 4, 4, 2, Batch Size: 64, Training Accuracy: 34.31%, Validation Accuracy: 33.31%, Precision: 25.95%, Recall: 33.31%, F1: 28.17%,loss_train:1.737006356809741,loss_val:1.7819605174207591,weight_decay:1e-05
# Early stopping at epoch 58
# Learning Rate: 0.001, Hidden Sizes: 4, 4, 2, Batch Size: 128, Training Accuracy: 34.08%, Validation Accuracy: 32.99%, Precision: 25.67%, Recall: 32.99%, F1: 26.10%,loss_train:1.7793535105649123,loss_val:1.8129826670103546,weight_decay:1e-05
# Early stopping at epoch 116
# Learning Rate: 0.001, Hidden Sizes: 8, 4, 2, Batch Size: 32, Training Accuracy: 40.52%, Validation Accuracy: 39.02%, Precision: 30.41%, Recall: 39.02%, F1: 33.00%,loss_train:1.5655845683554817,loss_val:1.6413982990111782,weight_decay:1e-05
# Early stopping at epoch 144
# Learning Rate: 0.001, Hidden Sizes: 8, 4, 2, Batch Size: 64, Training Accuracy: 40.91%, Validation Accuracy: 39.64%, Precision: 29.10%, Recall: 39.64%, F1: 31.64%,loss_train:1.5362207173182387,loss_val:1.6254788585018143,weight_decay:1e-05
# Early stopping at epoch 42
# Learning Rate: 0.001, Hidden Sizes: 8, 4, 2, Batch Size: 128, Training Accuracy: 36.31%, Validation Accuracy: 35.44%, Precision: 29.17%, Recall: 35.44%, F1: 31.03%,loss_train:1.6257547386790365,loss_val:1.6718941412729098,weight_decay:1e-05
# Early stopping at epoch 115
# Learning Rate: 0.001, Hidden Sizes: 16, 4, 2, Batch Size: 32, Training Accuracy: 50.52%, Validation Accuracy: 47.92%, Precision: 43.29%, Recall: 47.92%, F1: 44.79%,loss_train:1.3267610312390938,loss_val:1.4612451258600632,weight_decay:1e-05
# Early stopping at epoch 90
# Learning Rate: 0.001, Hidden Sizes: 16, 4, 2, Batch Size: 64, Training Accuracy: 47.22%, Validation Accuracy: 45.50%, Precision: 36.24%, Recall: 45.50%, F1: 39.39%,loss_train:1.3369397541626575,loss_val:1.4566920194535922,weight_decay:1e-05
# Early stopping at epoch 6
# Learning Rate: 0.001, Hidden Sizes: 16, 4, 2, Batch Size: 128, Training Accuracy: 11.29%, Validation Accuracy: 11.02%, Precision: 1.21%, Recall: 11.02%, F1: 2.19%,loss_train:2.300632225670256,loss_val:2.30106761562302,weight_decay:1e-05
# Early stopping at epoch 88
# Learning Rate: 0.001, Hidden Sizes: 32, 4, 2, Batch Size: 32, Training Accuracy: 50.55%, Validation Accuracy: 46.92%, Precision: 45.42%, Recall: 46.92%, F1: 44.60%,loss_train:1.229762468515896,loss_val:1.3717363270450385,weight_decay:1e-05
# Early stopping at epoch 88
# Learning Rate: 0.001, Hidden Sizes: 32, 4, 2, Batch Size: 64, Training Accuracy: 56.71%, Validation Accuracy: 52.94%, Precision: 48.79%, Recall: 52.94%, F1: 49.91%,loss_train:1.1685878190487038,loss_val:1.3309653826280203,weight_decay:1e-05
# Early stopping at epoch 117
# Learning Rate: 0.001, Hidden Sizes: 32, 4, 2, Batch Size: 128, Training Accuracy: 52.13%, Validation Accuracy: 48.10%, Precision: 40.42%, Recall: 48.10%, F1: 42.99%,loss_train:1.1598214502377102,loss_val:1.3359139310349202,weight_decay:1e-05
# Early stopping at epoch 106
# Learning Rate: 0.001, Hidden Sizes: 64, 4, 2, Batch Size: 32, Training Accuracy: 56.60%, Validation Accuracy: 52.58%, Precision: 47.00%, Recall: 52.58%, F1: 48.93%,loss_train:1.1475491832087255,loss_val:1.3614614129147034,weight_decay:1e-05
# Early stopping at epoch 110
# Learning Rate: 0.001, Hidden Sizes: 64, 4, 2, Batch Size: 64, Training Accuracy: 60.86%, Validation Accuracy: 55.29%, Precision: 50.48%, Recall: 55.29%, F1: 51.96%,loss_train:1.0608929189114993,loss_val:1.2900350709005501,weight_decay:1e-05
# Early stopping at epoch 91
# Learning Rate: 0.001, Hidden Sizes: 64, 4, 2, Batch Size: 128, Training Accuracy: 53.48%, Validation Accuracy: 50.05%, Precision: 40.20%, Recall: 50.05%, F1: 42.50%,loss_train:1.2132671763950316,loss_val:1.3746633814738127,weight_decay:1e-05
# Early stopping at epoch 103
# Learning Rate: 0.001, Hidden Sizes: 128, 4, 2, Batch Size: 32, Training Accuracy: 61.49%, Validation Accuracy: 56.57%, Precision: 54.09%, Recall: 56.57%, F1: 52.61%,loss_train:1.0172471604814946,loss_val:1.2391470137821285,weight_decay:1e-05
# Early stopping at epoch 130
# Learning Rate: 0.001, Hidden Sizes: 128, 4, 2, Batch Size: 64, Training Accuracy: 68.89%, Validation Accuracy: 62.38%, Precision: 62.18%, Recall: 62.38%, F1: 60.78%,loss_train:0.9338453650288415,loss_val:1.1683259841923581,weight_decay:1e-05
# Early stopping at epoch 28
# Learning Rate: 0.001, Hidden Sizes: 128, 4, 2, Batch Size: 128, Training Accuracy: 26.71%, Validation Accuracy: 26.52%, Precision: 19.44%, Recall: 26.52%, F1: 20.28%,loss_train:1.886282208095079,loss_val:1.8919901051991563,weight_decay:1e-05
# Early stopping at epoch 69
# Learning Rate: 0.001, Hidden Sizes: 256, 4, 2, Batch Size: 32, Training Accuracy: 47.31%, Validation Accuracy: 46.08%, Precision: 38.72%, Recall: 46.08%, F1: 39.91%,loss_train:1.3007200050379644,loss_val:1.3800836877996476,weight_decay:1e-05

# %%
param_grid = {
    'learning_rate': [0.001],
    'hidden_size_layer1': [256,512],
    'hidden_size_layer2': [256,512],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [256,512],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 54
# Learning Rate: 0.001, Hidden Sizes: 256, 256, 256, Batch Size: 32, Training Accuracy: 95.27%, Validation Accuracy: 90.26%, Precision: 90.41%, Recall: 90.26%, F1: 90.25%,loss_train:0.18235204318890044,loss_val:0.35652126417441843,weight_decay:1e-05
# Early stopping at epoch 72
# Learning Rate: 0.001, Hidden Sizes: 512, 256, 256, Batch Size: 32, Training Accuracy: 95.94%, Validation Accuracy: 91.38%, Precision: 91.59%, Recall: 91.38%, F1: 91.39%,loss_train:0.1644389003646022,loss_val:0.3470749257613976,weight_decay:1e-05
# Early stopping at epoch 63
# Learning Rate: 0.001, Hidden Sizes: 256, 512, 256, Batch Size: 32, Training Accuracy: 95.99%, Validation Accuracy: 90.83%, Precision: 91.06%, Recall: 90.83%, F1: 90.85%,loss_train:0.16241925211574149,loss_val:0.3586941795234401,weight_decay:1e-05
# Early stopping at epoch 75
# Learning Rate: 0.001, Hidden Sizes: 512, 512, 256, Batch Size: 32, Training Accuracy: 96.36%, Validation Accuracy: 91.55%, Precision: 91.65%, Recall: 91.55%, F1: 91.56%,loss_train:0.1593156985755766,loss_val:0.34452661221342495,weight_decay:1e-05
# Early stopping at epoch 62
# Learning Rate: 0.001, Hidden Sizes: 256, 256, 512, Batch Size: 32, Training Accuracy: 95.18%, Validation Accuracy: 90.33%, Precision: 90.47%, Recall: 90.33%, F1: 90.35%,loss_train:0.18406530507541838,loss_val:0.3844439646809499,weight_decay:1e-05
# Early stopping at epoch 70
# Learning Rate: 0.001, Hidden Sizes: 512, 256, 512, Batch Size: 32, Training Accuracy: 94.29%, Validation Accuracy: 90.22%, Precision: 90.58%, Recall: 90.22%, F1: 90.19%,loss_train:0.21615753562901832,loss_val:0.38906955154209,weight_decay:1e-05
# Early stopping at epoch 6
# Learning Rate: 0.001, Hidden Sizes: 256, 512, 512, Batch Size: 32, Training Accuracy: 20.13%, Validation Accuracy: 19.75%, Precision: 4.22%, Recall: 19.75%, F1: 6.92%,loss_train:3.909728639319572,loss_val:3.9443691613016334,weight_decay:1e-05
# Early stopping at epoch 6
# Learning Rate: 0.001, Hidden Sizes: 512, 512, 512, Batch Size: 32, Training Accuracy: 11.77%, Validation Accuracy: 11.48%, Precision: 9.54%, Recall: 11.48%, F1: 4.67%,loss_train:3.7472180030493916,loss_val:3.7792910674741838,weight_decay:1e-05

# %%
param_grid = {
    'learning_rate': [0.0005],
    'hidden_size_layer1': [256,512],
    'hidden_size_layer2': [256,512],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [256,512],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 96
# Learning Rate: 0.0005, Hidden Sizes: 256, 256, 256, Batch Size: 32, Training Accuracy: 95.64%, Validation Accuracy: 90.74%, Precision: 90.79%, Recall: 90.74%, F1: 90.74%,loss_train:0.17395224050933983,loss_val:0.3440202314873629,weight_decay:1e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-f825ad3675e4> in <cell line: 12>()
#      17                 for batch_size in param_grid['batch_size']:
#      18                     for epochs in param_grid['epochs']:
# ---> 19                         train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
#      20                             hidden_size_layer1,
#      21                             hidden_size_layer2,
#
# <ipython-input-22-a4e44cc50da0> in evaluate_model(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs, weight_decay, patience, min_delta)
#      18             batch_x = x_train[i * batch_size:(i + 1) * batch_size]
#      19             batch_y = y_train_one_hot[i * batch_size:(i + 1) * batch_size]
# ---> 20             model.train(batch_x, batch_y, 1)
#      21
#      22         # Đánh giá độ chính xác và loss trên tập validation
#
# <ipython-input-21-84128e8f0d89> in train(self, X, y, epochs)
#      64         for epoch in range(epochs):
#      65             self.forward(X)
# ---> 66             self.backward(X, y)
#      67
#      68     def evaluate(self, X, y):
#
# <ipython-input-21-84128e8f0d89> in backward(self, X, y)
#      58                 self.layers[i] -= (self.A_prev[i - 1].T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]) * self.learning_rate
#      59
# ---> 60             if i > 0:
#      61                 hidden_delta = hidden_delta.dot(self.layers[i].T) * self.sigmoid_derivative(self.A_prev[i - 1])
#      62
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Thay đổi: tạo range(epoch)
epochs_range = range(1, 117)

# Khởi tạo danh sách rỗng cho các chỉ số
train_loss, val_loss = [], []
train_accuracy, val_accuracy = [], []
train_recall, val_recall = [], []
train_f1, val_f1 = [], []
train_precision, val_precision = [], []

def evaluate_model_end(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs,weight_decay, patience=5, min_delta=0.001):
    model = SimpleNN(input_size=784,
                     hidden_size_layer1=hidden_size_layer1,
                     hidden_size_layer2=hidden_size_layer2,
                     hidden_size_layer3=hidden_size_layer3,
                     output_size=10,
                     learning_rate=learning_rate,
                     l2_lambda=weight_decay)
    best_accuracy = 0
    patience_counter = 0
    num_batches = int(np.ceil(len(x_train) / batch_size))

    for epoch in range(epochs):
        for i in range(num_batches):
            batch_x = x_train[i * batch_size:(i + 1) * batch_size]
            batch_y = y_train_one_hot[i * batch_size:(i + 1) * batch_size]
            model.train(batch_x, batch_y, 1)

        val_acc, val_loss_value = model.evaluate(x_val, y_val_one_hot)
        train_acc, train_loss_value = model.evaluate(x_train, y_train_one_hot)

        # Forward pass để lấy dự đoán
        train_predictions = model.forward(x_train)
        val_predictions = model.forward(x_val)

        # Chuyển đổi đầu ra thành nhãn phân loại
        train_predictions_labels = np.argmax(train_predictions, axis=1)
        val_predictions_labels = np.argmax(val_predictions, axis=1)
        true_labels_train = np.argmax(y_train_one_hot, axis=1)
        true_labels_val = np.argmax(y_val_one_hot, axis=1)

        # Tính toán các chỉ số
        precision_train = precision_score(true_labels_train, train_predictions_labels, average='weighted', zero_division=0)
        precision_val = precision_score(true_labels_val, val_predictions_labels, average='weighted', zero_division=0)
        recall_train = recall_score(true_labels_train, train_predictions_labels, average='weighted')
        recall_val = recall_score(true_labels_val, val_predictions_labels, average='weighted')
        f1_train = f1_score(true_labels_train, train_predictions_labels, average='weighted')
        f1_val = f1_score(true_labels_val, val_predictions_labels, average='weighted')

        # Append vào danh sách
        train_loss.append(train_loss_value)
        val_loss.append(val_loss_value)
        train_accuracy.append(train_acc)
        val_accuracy.append(val_acc)
        train_f1.append(f1_train)
        val_f1.append(f1_val)
        train_precision.append(precision_train)
        val_precision.append(precision_val)
        train_recall.append(recall_train)
        val_recall.append(recall_val)

    # Vẽ biểu đồ
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

    # Biểu đồ Loss & Accuracy
    ax1.plot(epochs_range, train_loss, 'b', label='Train Loss')
    ax1.plot(epochs_range, val_loss, 'g', label='Val Loss')
    ax1.plot(epochs_range, train_accuracy, 'c', label='Train Accuracy')
    ax1.plot(epochs_range, val_accuracy, 'r', label='Val Accuracy')
    ax1.set_title('Training and Validation Loss & Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss / Accuracy')
    ax1.legend()

    # Biểu đồ Recall, F1 Score và Precision
    ax2.plot(epochs_range, train_recall, 'c', label='Train Recall')
    ax2.plot(epochs_range, val_recall, 'm', label='Val Recall')
    ax2.plot(epochs_range, train_f1, 'y', label='Train F1 Score')
    ax2.plot(epochs_range, val_f1, 'k', label='Val F1 Score')
    ax2.plot(epochs_range, train_precision, 'g', label='Train Precision')
    ax2.plot(epochs_range, val_precision, 'r', label='Val Precision')
    ax2.set_title('Training and Validation Recall, F1 Score, & Precision')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Score')
    ax2.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Viết lại hàm (thêm vẽ biểu đồ để xem sự biến đổi theo thời gian của các chỉ số nêu trên)

# %%
evaluate_model_end( 512,
                128,
                None,
                0.001,
                128,
                x_train,
                y_train_one_hot,
                x_val,
                y_val_one_hot,
                epochs=116,
                weight_decay=0.00001)

# %%
x_train=np.concatenate([x_train, x_val])
y_train_one_hot=np.concatenate([y_train_one_hot, y_val_one_hot])
import joblib
final_model = SimpleNN(input_size=784,
                     hidden_size_layer1=512,
                     hidden_size_layer2=128,
                     hidden_size_layer3=None,
                     output_size=10,
                     learning_rate=0.001, l2_lambda=0.00001)
num_batches = int(np.ceil(len(x_train) / 128))
for epoch in range(116):
    for i in range(num_batches):
        batch_x = x_train[i * 128:(i + 1) * 128]
        batch_y = y_train_one_hot[i * 128:(i + 1) * 128]  # Sử dụng nhãn one-hot
        final_model.train(batch_x, batch_y, 1)
joblib.dump(final_model, 'best_simple_nn_model.pkl')
print("Mô hình đã được lưu vào 'best_simple_nn_model.pkl'")
# Out:
# Mô hình đã được lưu vào 'best_simple_nn_model.pkl'

# %%
# Tải mô hình
loaded_model = joblib.load('best_simple_nn_model.pkl')

# Sử dụng mô hình để dự đoán
test_accuracy,loss = loaded_model.evaluate(x_test, y_test_one_hot)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Loss: {loss}')
# Out:
# Test Accuracy: 89.36%
# Loss: 0.48496332324083236

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# Dự đoán nhãn
y_pred = loaded_model.forward(x_test)

# Chuyển đổi từ one-hot encoding sang nhãn
y_test_labels = np.argmax(y_test_one_hot, axis=1)
y_pred_labels = np.argmax(y_pred, axis=1)

# Tạo Confusion Matrix
cm = confusion_matrix(y_test_labels, y_pred_labels)

# Hiển thị Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')  # Sử dụng bảng màu bạn muốn

# %%
# Tải mô hình
loaded_model = joblib.load('best_simple_nn_model.pkl')

# Sử dụng mô hình để dự đoán
test_accuracy,loss = loaded_model.evaluate(x_train, y_train_one_hot)
print(f'train Accuracy: {test_accuracy * 100:.2f}%')
print(f'Loss: {loss}')
# Out:
# train Accuracy: 98.90%
# Loss: 0.10086891582603782
