# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices)!=0: #Use GPU for better experience
  tf.config.experimental.set_memory_growth(physical_devices[0],True)
print(physical_devices)

# %%
(x_train,y_train), (x_test,y_test) = mnist.load_data()
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# %%
fig, axes = plt.subplots(10, 10, figsize=(10, 10))
fig.subplots_adjust(hspace=0.3, wspace=0.3)

for label in range(10):
    indices = np.where(y_train == label)[0][:10]
    for i, idx in enumerate(indices):
        ax = axes[label, i]
        ax.imshow(x_train[idx], cmap='gray')
        ax.axis('off')

plt.show()

# %%
train_label_counts = np.bincount(y_train, minlength=10)
test_label_counts = np.bincount(y_test, minlength=10)

fig, ax = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle('Distribution of Labels in the MNIST Dataset')

ax[0].bar(range(10), train_label_counts, color='skyblue')
ax[0].set_xlabel('Label')
ax[0].set_ylabel('Frequency')
ax[0].set_title('Training Set')
ax[0].set_xticks(range(10))
ax[0].set_ylim(4000, max(train_label_counts) + 500)
for i, count in enumerate(train_label_counts):
    ax[0].text(i, count + 100, str(count), ha='center', color='black', fontsize=12)

ax[1].bar(range(10), test_label_counts, color='salmon')
ax[1].set_xlabel('Label')
ax[1].set_title('Test Set')
ax[1].set_xticks(range(10))
ax[1].set_ylim(600, max(test_label_counts) + 100)
for i, count in enumerate(test_label_counts):
    ax[1].text(i, count + 20, str(count), ha='center', color='black', fontsize=12)

plt.show()

# %%
x_train = x_train.astype('float32')/255.0
x_test = x_test.astype('float32')/255.0

# %%
print(x_train.shape)
print(type(x_train))
print(max(x_train.flatten()),min(x_train.flatten()))
print(x_test.shape)
print(type(x_test))
print(max(x_test.flatten()),min(x_test.flatten()))
# Out:
# (60000, 28, 28)
# <class 'numpy.ndarray'>
# 1.0 0.0
# (10000, 28, 28)
# <class 'numpy.ndarray'>
# 1.0 0.0

# %%
from scipy.ndimage import rotate, gaussian_filter

#Rotation 30 deg maximum, just to make sure the labels wont mess up such as 9 and 6 or 2 and 5 or even 1 and 7
def random_rotate_image_2d(image, max_angle=30):
    angle = np.random.uniform(-max_angle, max_angle)
    rotated_image = rotate(image, angle, reshape=False, mode='nearest')
    return rotated_image

#Shift images horizontaly or vertically a few pixels
def shift_image(image, max_offset=3):
    offset_x = np.random.randint(-max_offset, max_offset + 1)
    offset_y = np.random.randint(-max_offset, max_offset + 1)
    return np.roll(np.roll(image.reshape(28, 28), offset_x, axis=1), offset_y, axis=0)

#Add gaussian noise
def add_gaussian_noise(image, mean=0,std=0.1):
    noise = np.random.normal(mean, std, image.shape)
    return np.clip(image + noise, 0, 1) #Remember to use with the normalized image pumpkin

def reduce_noise(image, sigma=0.5):
  return gaussian_filter(image, sigma=sigma)

def augment(image):
  image = random_rotate_image_2d(image)
  image = shift_image(image)
  image = add_gaussian_noise(image)
  image = reduce_noise(image)
  return image

# %%
num_images = 5

plt.figure(figsize=(10, 4))

for i in range(num_images):
    idx = np.random.randint(0, x_train.shape[0])
    original_image = x_train[idx]
    augmented_image = augment(original_image)

    plt.subplot(2, num_images, i + 1)
    plt.imshow(original_image, cmap='gray')
    plt.axis('off')
    plt.title("Original")

    plt.subplot(2, num_images, num_images + i + 1)
    plt.imshow(augmented_image, cmap='gray')
    plt.axis('off')
    plt.title("Augmented")

plt.tight_layout()
plt.show()

# %%
x_train = np.array([augment(image) for image in x_train])

# %%
fig, axes = plt.subplots(10, 10, figsize=(10, 10))
fig.subplots_adjust(hspace=0.3, wspace=0.3)

for label in range(10):
    indices = np.where(y_train == label)[0][:10]
    for i, idx in enumerate(indices):
        ax = axes[label, i]
        ax.imshow(x_train[idx], cmap='gray')
        ax.axis('off')

plt.show()

# %%
x_train = x_train.reshape(-1,28*28)
x_test = x_test.reshape(-1,28*28)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
param_grid = {
    'learning_rate': [0.00001,0.0001,0.001],
    'hidden_size_layer1': [2,4,8,16,32,64],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32, 64, 128],
    'weight_decay':[0.00001],
    'epochs': [5000]#vì dùng early stop nên cho một số epochs to hẳn
}

# %% [markdown]
# Cấu hình để thử từng trường hợp nhằm tìm ra chỉ số có accuracy tốt nhất

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# Tách tập train thành 2 tập là train và valid

# %%
train_label_counts = np.bincount(y_train, minlength=10)
val_label_counts = np.bincount(y_val, minlength=10)

fig, ax = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle('Distribution of Labels in the MNIST Dataset')

ax[0].bar(range(10), train_label_counts, color='skyblue')
ax[0].set_xlabel('Label')
ax[0].set_ylabel('Frequency')
ax[0].set_title('Training Set')
ax[0].set_xticks(range(10))
ax[0].set_ylim(4000, max(train_label_counts) + 500)
for i, count in enumerate(train_label_counts):
    ax[0].text(i, count + 100, str(count), ha='center', color='black', fontsize=12)

ax[1].bar(range(10), val_label_counts, color='salmon')
ax[1].set_xlabel('Label')
ax[1].set_title('Val Set')
ax[1].set_xticks(range(10))
ax[1].set_ylim(600, max(test_label_counts) + 100)
for i, count in enumerate(test_label_counts):
    ax[1].text(i, count + 20, str(count), ha='center', color='black', fontsize=12)

plt.show()

# %%
print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
# Out:
# (48000, 784)
# (48000,)
# (12000, 784)
# (12000,)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False)
y_train_one_hot = encoder.fit_transform(y_train.reshape(-1, 1))
y_val_one_hot = encoder.transform(y_val.reshape(-1, 1))
y_test_one_hot = encoder.transform(y_test.reshape(-1, 1))

# %% [markdown]
# chuyển đổi mảng Y từ mảng 1 chiều sang mảng n chiều mỗi chiều có 10 phần tử tượng chưng cho 10 số (ví dụ số 0 là 1 0 0 0 ...,1 là 0 1 0 0 ...)

# %%
print(y_train_one_hot.shape)
print(y_val_one_hot.shape)
print(y_test_one_hot.shape)
# Out:
# (48000, 10)
# (12000, 10)
# (10000, 10)

# %%
import numpy as np

class SimpleNN:
    def __init__(self, input_size, hidden_size_layer1, hidden_size_layer2=None, hidden_size_layer3=None, output_size=1, learning_rate=0.01, l2_lambda=0.001, momentum=0.99):
        self.learning_rate = learning_rate
        self.layers = []
        self.A_prev = []  # Dùng để lưu các kết quả
        self.l2_lambda = l2_lambda
        self.momentum = momentum

        # Khởi tạo trọng số với Xavier Initialization
        self.layers.append(np.random.randn(input_size, hidden_size_layer1) * np.sqrt(2 / (input_size + hidden_size_layer1)))

        if hidden_size_layer2 is not None:
            self.layers.append(np.random.randn(hidden_size_layer1, hidden_size_layer2) * np.sqrt(2 / (hidden_size_layer1 + hidden_size_layer2)))

        if hidden_size_layer3 is not None:
            self.layers.append(np.random.randn(hidden_size_layer2 if hidden_size_layer2 is not None else hidden_size_layer1, hidden_size_layer3) * np.sqrt(2 / ((hidden_size_layer2 if hidden_size_layer2 is not None else hidden_size_layer1) + hidden_size_layer3)))

        self.W_output = np.random.randn((hidden_size_layer3 if hidden_size_layer3 is not None else (hidden_size_layer2 if hidden_size_layer2 is not None else hidden_size_layer1)), output_size) * np.sqrt(2 / ((hidden_size_layer3 if hidden_size_layer3 is not None else (hidden_size_layer2 if hidden_size_layer2 is not None else hidden_size_layer1)) + output_size))

        # Khởi tạo biến momentum cho các trọng số
        self.velocity_layers = [np.zeros_like(layer) for layer in self.layers]
        self.velocity_output = np.zeros_like(self.W_output)

    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def sigmoid_derivative(self, z):
        return z * (1 - z)

    def soft_max(self, z):
        z_max = np.max(z, axis=1, keepdims=True)
        e_z = np.exp(z - z_max)
        return e_z / np.sum(e_z, axis=1, keepdims=True)

    def loss_function(self, output, y):
        return -np.sum(y * np.log(output)) / y.shape[0] + self.l2_lambda * np.sum([np.sum(np.square(layer)) for layer in self.layers]) + self.l2_lambda * np.sum(np.square(self.W_output))

    def forward(self, X):
        self.A = X
        self.A_prev = []

        for W in self.layers:
            self.Z = np.dot(self.A, W)
            self.A = self.sigmoid(self.Z)
            self.A_prev.append(self.A)

        self.Z_output = np.dot(self.A, self.W_output)
        self.A_output = self.soft_max(self.Z_output)
        return self.A_output

    def backward(self, X, y):
        output_delta = self.A_output - y
        # Cập nhật trọng số đầu ra với momentum
        grad_output = self.A.T.dot(output_delta) + 2 * self.l2_lambda * self.W_output
        self.velocity_output = self.momentum * self.velocity_output - self.learning_rate * grad_output
        self.W_output += self.velocity_output

        hidden_delta = output_delta.dot(self.W_output.T) * self.sigmoid_derivative(self.A_prev[-1])

        for i in reversed(range(len(self.layers))):
            if i == 0:
                grad_hidden = X.T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]
                self.velocity_layers[i] = self.momentum * self.velocity_layers[i] - self.learning_rate * grad_hidden
                self.layers[i] += self.velocity_layers[i]
            else:
                grad_hidden = self.A_prev[i - 1].T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]
                self.velocity_layers[i] = self.momentum * self.velocity_layers[i] - self.learning_rate * grad_hidden
                self.layers[i] += self.velocity_layers[i]

            if i > 0:
                hidden_delta = hidden_delta.dot(self.layers[i].T) * self.sigmoid_derivative(self.A_prev[i - 1])

    def train(self, X, y, epochs):
        for epoch in range(epochs):
            self.forward(X)
            self.backward(X, y)

    def evaluate(self, X, y):
        output = self.forward(X)
        predictions = np.argmax(output, axis=1)
        true_labels = np.argmax(y, axis=1)
        accuracy = np.mean(predictions == true_labels)
        loss = self.loss_function(output, y)
        return accuracy, loss

# %% [markdown]
# Tạo mạng
# +) công thức tính hàm cross-entropy(chưa phạt L2) và đạo hàm của hàm cross-entropy
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_model(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs,weight_decay, patience=5, min_delta=0.001):
    model = SimpleNN(input_size=784,
                     hidden_size_layer1=hidden_size_layer1,
                     hidden_size_layer2=hidden_size_layer2,
                     hidden_size_layer3=hidden_size_layer3,
                     output_size=10,
                     learning_rate=learning_rate,
                     l2_lambda=weight_decay)
    best_accuracy = 0
    best_loss = float('inf')
    patience_counter = 0
    num_batches = int(np.ceil(len(x_train) / batch_size))

    for epoch in range(epochs):
        for i in range(num_batches):
            batch_x = x_train[i * batch_size:(i + 1) * batch_size]
            batch_y = y_train_one_hot[i * batch_size:(i + 1) * batch_size]
            model.train(batch_x, batch_y, 1)

        # Đánh giá độ chính xác và loss trên tập validation
        val_accuracy, val_loss = model.evaluate(x_val, y_val_one_hot)

        # Kiểm tra điều kiện early stopping
        if val_loss < best_loss - min_delta:
            best_loss = min(best_loss, val_loss)
            best_accuracy = max(best_accuracy, val_accuracy)
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f'Early stopping at epoch {epoch + 1}')
                break

        # Thông báo nếu loss đạt ngưỡng rất thấp
        if val_loss < 1e-8:
            print(f'Early stopping at epoch {epoch + 1} because loss_function is very low: {val_loss}')
            break

    # Đánh giá mô hình trên tập huấn luyện và tập xác thực
    train_accuracy, train_loss = model.evaluate(x_train, y_train_one_hot)
    val_accuracy, val_loss = model.evaluate(x_val, y_val_one_hot)

    # Dự đoán và tính các chỉ số trên tập huấn luyện và tập validation
    train_predictions = model.forward(x_train)
    val_predictions = model.forward(x_val)
    train_predictions_labels = np.argmax(train_predictions, axis=1)
    val_predictions_labels = np.argmax(val_predictions, axis=1)
    true_labels_train = np.argmax(y_train_one_hot, axis=1)
    true_labels_val = np.argmax(y_val_one_hot, axis=1)

    # Tính toán precision, recall, và F1-score
    precision = precision_score(true_labels_val, val_predictions_labels, average='weighted', zero_division=0)
    recall = recall_score(true_labels_val, val_predictions_labels, average='weighted')
    f1 = f1_score(true_labels_val, val_predictions_labels, average='weighted')

    return train_accuracy, val_accuracy, precision, recall, f1, train_loss, val_loss

# %% [markdown]
# xây dựng hàm đánh giá áp dụng early stop với patience là 5 tức là khi độ chính xác không tăng trong 5 lần liên tiếp sẽ lập tức dừng

# %% [markdown]
# # BẮT ĐẦU TÌM KIẾM HYPERPARAMS với một vài số ngẫu nhiên

# %%
param_grid = {
    'learning_rate': [0.0001,0.001],
    'hidden_size_layer1': [2,4,8,16,32,64],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32, 64, 128],
    'weight_decay':[0.00001,0.0001],
    'epochs': [5000]#vì dùng early stop nên cho một số epochs to hẳn
}
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 20
# Learning Rate: 0.0001, Hidden Sizes: 2, None, None, Batch Size: 32, Training Accuracy: 26.97%, Validation Accuracy: 26.94%, Precision: 10.80%, Recall: 26.94%, F1: 14.75%,loss_train:1.9279322261288199,loss_val:1.9489178771424793,weight_decay:1e-05
# Early stopping at epoch 16
# Learning Rate: 0.0001, Hidden Sizes: 2, None, None, Batch Size: 64, Training Accuracy: 26.23%, Validation Accuracy: 25.57%, Precision: 12.17%, Recall: 25.57%, F1: 15.96%,loss_train:1.9345018153271365,loss_val:1.9662643933967232,weight_decay:1e-05
# Early stopping at epoch 14
# Learning Rate: 0.0001, Hidden Sizes: 2, None, None, Batch Size: 128, Training Accuracy: 25.75%, Validation Accuracy: 25.42%, Precision: 10.13%, Recall: 25.42%, F1: 14.09%,loss_train:1.9276830520724622,loss_val:1.9513896063186327,weight_decay:1e-05
# Early stopping at epoch 37
# Learning Rate: 0.0001, Hidden Sizes: 4, None, None, Batch Size: 32, Training Accuracy: 47.30%, Validation Accuracy: 45.84%, Precision: 40.95%, Recall: 45.84%, F1: 41.42%,loss_train:1.4867125015532006,loss_val:1.5347846993713887,weight_decay:1e-05
# Early stopping at epoch 11
# Learning Rate: 0.0001, Hidden Sizes: 4, None, None, Batch Size: 64, Training Accuracy: 40.44%, Validation Accuracy: 39.22%, Precision: 34.05%, Recall: 39.22%, F1: 35.01%,loss_train:1.7021103454393178,loss_val:1.7415087611000335,weight_decay:1e-05
# Early stopping at epoch 16
# Learning Rate: 0.0001, Hidden Sizes: 4, None, None, Batch Size: 128, Training Accuracy: 37.88%, Validation Accuracy: 36.82%, Precision: 31.57%, Recall: 36.82%, F1: 29.39%,loss_train:1.7190468862095345,loss_val:1.7543574397859254,weight_decay:1e-05
# Early stopping at epoch 18
# Learning Rate: 0.0001, Hidden Sizes: 8, None, None, Batch Size: 32, Training Accuracy: 61.88%, Validation Accuracy: 59.43%, Precision: 58.84%, Recall: 59.43%, F1: 58.41%,loss_train:1.133889704742273,loss_val:1.2221229690929276,weight_decay:1e-05
# Early stopping at epoch 31
# Learning Rate: 0.0001, Hidden Sizes: 8, None, None, Batch Size: 64, Training Accuracy: 61.95%, Validation Accuracy: 59.17%, Precision: 58.64%, Recall: 59.17%, F1: 57.65%,loss_train:1.1124978674484887,loss_val:1.189900892703168,weight_decay:1e-05
# Early stopping at epoch 22
# Learning Rate: 0.0001, Hidden Sizes: 8, None, None, Batch Size: 128, Training Accuracy: 60.91%, Validation Accuracy: 57.38%, Precision: 57.28%, Recall: 57.38%, F1: 56.44%,loss_train:1.1812129322248979,loss_val:1.2790408383446483,weight_decay:1e-05
# Early stopping at epoch 24
# Learning Rate: 0.0001, Hidden Sizes: 16, None, None, Batch Size: 32, Training Accuracy: 78.53%, Validation Accuracy: 74.48%, Precision: 74.45%, Recall: 74.48%, F1: 74.30%,loss_train:0.699888406071318,loss_val:0.8401216533957303,weight_decay:1e-05
# Early stopping at epoch 18
# Learning Rate: 0.0001, Hidden Sizes: 16, None, None, Batch Size: 64, Training Accuracy: 78.31%, Validation Accuracy: 74.54%, Precision: 74.55%, Recall: 74.54%, F1: 74.39%,loss_train:0.7099390918012223,loss_val:0.8549535630721448,weight_decay:1e-05
# Early stopping at epoch 22
# Learning Rate: 0.0001, Hidden Sizes: 16, None, None, Batch Size: 128, Training Accuracy: 76.69%, Validation Accuracy: 72.50%, Precision: 72.90%, Recall: 72.50%, F1: 72.56%,loss_train:0.7408615544208963,loss_val:0.8956155068850398,weight_decay:1e-05
# Early stopping at epoch 20
# Learning Rate: 0.0001, Hidden Sizes: 32, None, None, Batch Size: 32, Training Accuracy: 88.88%, Validation Accuracy: 83.90%, Precision: 84.00%, Recall: 83.90%, F1: 83.86%,loss_train:0.38681036675913716,loss_val:0.5640698749315821,weight_decay:1e-05
# Early stopping at epoch 16
# Learning Rate: 0.0001, Hidden Sizes: 32, None, None, Batch Size: 64, Training Accuracy: 87.76%, Validation Accuracy: 83.49%, Precision: 83.49%, Recall: 83.49%, F1: 83.40%,loss_train:0.4161600572357311,loss_val:0.557132540401619,weight_decay:1e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-b1f39c698e4d> in <cell line: 12>()
#      17                 for batch_size in param_grid['batch_size']:
#      18                     for epochs in param_grid['epochs']:
# ---> 19                         train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
#      20                             hidden_size_layer1,
#      21                             hidden_size_layer2,
#
# <ipython-input-21-a4e44cc50da0> in evaluate_model(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs, weight_decay, patience, min_delta)
#      18             batch_x = x_train[i * batch_size:(i + 1) * batch_size]
#      19             batch_y = y_train_one_hot[i * batch_size:(i + 1) * batch_size]
# ---> 20             model.train(batch_x, batch_y, 1)
#      21
#      22         # Đánh giá độ chính xác và loss trên tập validation
#
# <ipython-input-23-1d0fc509549b> in train(self, X, y, epochs)
#      76         for epoch in range(epochs):
#      77             self.forward(X)
# ---> 78             self.backward(X, y)
#      79
#      80     def evaluate(self, X, y):
#
# <ipython-input-23-1d0fc509549b> in backward(self, X, y)
#      62         for i in reversed(range(len(self.layers))):
#      63             if i == 0:
# ---> 64                 grad_hidden = X.T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]
#      65                 self.velocity_layers[i] = self.momentum * self.velocity_layers[i] - self.learning_rate * grad_hidden
#      66                 self.layers[i] += self.velocity_layers[i]
#
# KeyboardInterrupt:

# %% [markdown]
# # mô hình underfit giảm learning rate

# %%
param_grid = {
    'learning_rate': [0.00005],
    'hidden_size_layer1': [2,4,8,16,32,64],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 82
# Learning Rate: 5e-05, Hidden Sizes: 2, None, None, Batch Size: 32, Training Accuracy: 27.15%, Validation Accuracy: 26.42%, Precision: 14.79%, Recall: 26.42%, F1: 17.30%,loss_train:1.9196505713692829,loss_val:1.9436012443296389,weight_decay:1e-05
# Early stopping at epoch 98
# Learning Rate: 5e-05, Hidden Sizes: 4, None, None, Batch Size: 32, Training Accuracy: 46.90%, Validation Accuracy: 46.17%, Precision: 43.72%, Recall: 46.17%, F1: 43.49%,loss_train:1.5039484654045312,loss_val:1.534437563713872,weight_decay:1e-05
# Early stopping at epoch 215
# Learning Rate: 5e-05, Hidden Sizes: 8, None, None, Batch Size: 32, Training Accuracy: 65.66%, Validation Accuracy: 62.63%, Precision: 61.95%, Recall: 62.63%, F1: 62.07%,loss_train:1.0388440767426383,loss_val:1.130456387328853,weight_decay:1e-05
# Early stopping at epoch 150
# Learning Rate: 5e-05, Hidden Sizes: 16, None, None, Batch Size: 32, Training Accuracy: 79.79%, Validation Accuracy: 76.07%, Precision: 75.98%, Recall: 76.07%, F1: 75.95%,loss_train:0.6596688639859137,loss_val:0.7685227955853697,weight_decay:1e-05
# Early stopping at epoch 172
# Learning Rate: 5e-05, Hidden Sizes: 32, None, None, Batch Size: 32, Training Accuracy: 88.91%, Validation Accuracy: 84.82%, Precision: 84.83%, Recall: 84.82%, F1: 84.80%,loss_train:0.3962568652738823,loss_val:0.5123795543706429,weight_decay:1e-05
# Early stopping at epoch 167
# Learning Rate: 5e-05, Hidden Sizes: 64, None, None, Batch Size: 32, Training Accuracy: 93.78%, Validation Accuracy: 89.40%, Precision: 89.43%, Recall: 89.40%, F1: 89.40%,loss_train:0.2526317295975607,loss_val:0.36869587026211087,weight_decay:1e-05

# %%
param_grid = {
    'learning_rate': [0.00005],
    'hidden_size_layer1': [128,256,512],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 183
# Learning Rate: 5e-05, Hidden Sizes: 128, None, None, Batch Size: 32, Training Accuracy: 96.06%, Validation Accuracy: 91.33%, Precision: 91.32%, Recall: 91.33%, F1: 91.32%,loss_train:0.18498884128001164,loss_val:0.3095505446191811,weight_decay:1e-05
# Early stopping at epoch 202
# Learning Rate: 5e-05, Hidden Sizes: 256, None, None, Batch Size: 32, Training Accuracy: 97.08%, Validation Accuracy: 92.40%, Precision: 92.40%, Recall: 92.40%, F1: 92.38%,loss_train:0.15810547498013022,loss_val:0.2869248628165928,weight_decay:1e-05
# Early stopping at epoch 212
# Learning Rate: 5e-05, Hidden Sizes: 512, None, None, Batch Size: 32, Training Accuracy: 97.30%, Validation Accuracy: 92.39%, Precision: 92.39%, Recall: 92.39%, F1: 92.38%,loss_train:0.15499120725391358,loss_val:0.28590074087237594,weight_decay:1e-05

# %%
param_grid = {
    'learning_rate': [0.00005],
    'hidden_size_layer1': [2,4,6,8,16,32],
    'hidden_size_layer2': [2,4,6,8,16,32],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 141
# Learning Rate: 5e-05, Hidden Sizes: 2, 2, None, Batch Size: 32, Training Accuracy: 26.58%, Validation Accuracy: 25.87%, Precision: 15.62%, Recall: 25.87%, F1: 18.96%,loss_train:1.900217999468593,loss_val:1.9157754637143969,weight_decay:1e-05
# Early stopping at epoch 114
# Learning Rate: 5e-05, Hidden Sizes: 4, 2, None, Batch Size: 32, Training Accuracy: 34.87%, Validation Accuracy: 34.44%, Precision: 25.02%, Recall: 34.44%, F1: 26.93%,loss_train:1.738437787398463,loss_val:1.7762198767728408,weight_decay:1e-05
# Early stopping at epoch 133
# Learning Rate: 5e-05, Hidden Sizes: 6, 2, None, Batch Size: 32, Training Accuracy: 37.97%, Validation Accuracy: 36.85%, Precision: 29.24%, Recall: 36.85%, F1: 31.58%,loss_train:1.6606351689267063,loss_val:1.7121427353154226,weight_decay:1e-05
# Early stopping at epoch 124
# Learning Rate: 5e-05, Hidden Sizes: 8, 2, None, Batch Size: 32, Training Accuracy: 40.80%, Validation Accuracy: 38.80%, Precision: 35.63%, Recall: 38.80%, F1: 34.94%,loss_train:1.524080748114673,loss_val:1.578691864620318,weight_decay:1e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-5787a1deb636> in <cell line: 12>()
#      17                 for batch_size in param_grid['batch_size']:
#      18                     for epochs in param_grid['epochs']:
# ---> 19                         train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
#      20                             hidden_size_layer1,
#      21                             hidden_size_layer2,
#
# <ipython-input-21-a4e44cc50da0> in evaluate_model(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs, weight_decay, patience, min_delta)
#      18             batch_x = x_train[i * batch_size:(i + 1) * batch_size]
#      19             batch_y = y_train_one_hot[i * batch_size:(i + 1) * batch_size]
# ---> 20             model.train(batch_x, batch_y, 1)
#      21
#      22         # Đánh giá độ chính xác và loss trên tập validation
#
# <ipython-input-20-7c6803f83364> in train(self, X, y, epochs)
#      75     def train(self, X, y, epochs):
#      76         for epoch in range(epochs):
# ---> 77             self.forward(X)
#      78             self.backward(X, y)
#      79
#
# <ipython-input-20-7c6803f83364> in forward(self, X)
#      44         for W in self.layers:
#      45             self.Z = np.dot(self.A, W)
# ---> 46             self.A = self.sigmoid(self.Z)
#      47             self.A_prev.append(self.A)
#      48
#
# <ipython-input-20-7c6803f83364> in sigmoid(self, z)
#      25
#      26     def sigmoid(self, z):
# ---> 27         return 1 / (1 + np.exp(-z))
#      28
#      29     def sigmoid_derivative(self, z):
#
# KeyboardInterrupt:

# %%
param_grid = {
    'learning_rate': [0.00005],
    'hidden_size_layer1': [128,256,512],
    'hidden_size_layer2': [128,256,512],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 118
# Learning Rate: 5e-05, Hidden Sizes: 128, 128, None, Batch Size: 32, Training Accuracy: 96.18%, Validation Accuracy: 91.35%, Precision: 91.36%, Recall: 91.35%, F1: 91.34%,loss_train:0.16131820236680727,loss_val:0.30408673756216514,weight_decay:1e-05
# Early stopping at epoch 129
# Learning Rate: 5e-05, Hidden Sizes: 256, 128, None, Batch Size: 32, Training Accuracy: 97.10%, Validation Accuracy: 91.92%, Precision: 91.93%, Recall: 91.92%, F1: 91.91%,loss_train:0.14165204915355242,loss_val:0.2914450447727952,weight_decay:1e-05
# Early stopping at epoch 147
# Learning Rate: 5e-05, Hidden Sizes: 512, 128, None, Batch Size: 32, Training Accuracy: 97.48%, Validation Accuracy: 92.27%, Precision: 92.28%, Recall: 92.27%, F1: 92.26%,loss_train:0.13359512278789387,loss_val:0.2857423786802662,weight_decay:1e-05
# Early stopping at epoch 119
# Learning Rate: 5e-05, Hidden Sizes: 128, 256, None, Batch Size: 32, Training Accuracy: 96.19%, Validation Accuracy: 91.10%, Precision: 91.14%, Recall: 91.10%, F1: 91.09%,loss_train:0.16335805834507316,loss_val:0.31139701170449946,weight_decay:1e-05
# Early stopping at epoch 125
# Learning Rate: 5e-05, Hidden Sizes: 256, 256, None, Batch Size: 32, Training Accuracy: 97.05%, Validation Accuracy: 91.99%, Precision: 92.00%, Recall: 91.99%, F1: 91.98%,loss_train:0.1434605781909761,loss_val:0.2900543918181277,weight_decay:1e-05
# Early stopping at epoch 139
# Learning Rate: 5e-05, Hidden Sizes: 512, 256, None, Batch Size: 32, Training Accuracy: 97.32%, Validation Accuracy: 92.33%, Precision: 92.36%, Recall: 92.33%, F1: 92.33%,loss_train:0.1372629259856969,loss_val:0.2922155731907207,weight_decay:1e-05
# Early stopping at epoch 118
# Learning Rate: 5e-05, Hidden Sizes: 128, 512, None, Batch Size: 32, Training Accuracy: 96.11%, Validation Accuracy: 90.79%, Precision: 90.80%, Recall: 90.79%, F1: 90.78%,loss_train:0.16412111418955033,loss_val:0.3190818670270401,weight_decay:1e-05
# Early stopping at epoch 129
# Learning Rate: 5e-05, Hidden Sizes: 256, 512, None, Batch Size: 32, Training Accuracy: 97.19%, Validation Accuracy: 92.06%, Precision: 92.07%, Recall: 92.06%, F1: 92.05%,loss_train:0.13814109263344185,loss_val:0.2954668381510046,weight_decay:1e-05
# Early stopping at epoch 132
# Learning Rate: 5e-05, Hidden Sizes: 512, 512, None, Batch Size: 32, Training Accuracy: 97.03%, Validation Accuracy: 92.04%, Precision: 92.04%, Recall: 92.04%, F1: 92.03%,loss_train:0.14788869988723294,loss_val:0.29896584043568164,weight_decay:1e-05

# %% [markdown]
# Khi tăng số lượng layers lên accuracy trên tập val không tăng vậy tham số lựa chọn sẽ là 256 ,learning rate:0.00001,weight_decay:0.00001,thử với các batchsize khác

# %%
param_grid = {
    'learning_rate': [0.00005],
    'hidden_size_layer1': [256],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [64,128],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 190
# Learning Rate: 5e-05, Hidden Sizes: 256, None, None, Batch Size: 64, Training Accuracy: 96.80%, Validation Accuracy: 92.37%, Precision: 92.39%, Recall: 92.37%, F1: 92.37%,loss_train:0.16486012282054496,loss_val:0.28560544101663726,weight_decay:1e-05
# Early stopping at epoch 188
# Learning Rate: 5e-05, Hidden Sizes: 256, None, None, Batch Size: 128, Training Accuracy: 96.94%, Validation Accuracy: 92.56%, Precision: 92.59%, Recall: 92.56%, F1: 92.56%,loss_train:0.16528795297858143,loss_val:0.2873687346258936,weight_decay:1e-05

# %% [markdown]
# #Thử tăng Momentum lên 0.99

# %%
param_grid = {
    'learning_rate': [0.00001],
    'hidden_size_layer1': [2,4,8,16,32,64],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32],
    'weight_decay':[0.00001],
    'epochs': [5000]#vì dùng early stop nên cho một số epochs to hẳn
}
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 43
# Learning Rate: 1e-05, Hidden Sizes: 2, None, None, Batch Size: 32, Training Accuracy: 28.05%, Validation Accuracy: 27.18%, Precision: 15.08%, Recall: 27.18%, F1: 18.97%,loss_train:1.926515141010811,loss_val:1.9536916590379148,weight_decay:1e-05
# Early stopping at epoch 73
# Learning Rate: 1e-05, Hidden Sizes: 4, None, None, Batch Size: 32, Training Accuracy: 51.52%, Validation Accuracy: 50.02%, Precision: 47.60%, Recall: 50.02%, F1: 47.64%,loss_train:1.4261877885256302,loss_val:1.4674261994685798,weight_decay:1e-05
# Early stopping at epoch 128
# Learning Rate: 1e-05, Hidden Sizes: 8, None, None, Batch Size: 32, Training Accuracy: 66.94%, Validation Accuracy: 64.22%, Precision: 63.44%, Recall: 64.22%, F1: 63.70%,loss_train:1.0346023907494641,loss_val:1.1130913835449696,weight_decay:1e-05
# Early stopping at epoch 102
# Learning Rate: 1e-05, Hidden Sizes: 16, None, None, Batch Size: 32, Training Accuracy: 79.92%, Validation Accuracy: 75.86%, Precision: 76.07%, Recall: 75.86%, F1: 75.86%,loss_train:0.6719249725533477,loss_val:0.788013136481619,weight_decay:1e-05
# Early stopping at epoch 102
# Learning Rate: 1e-05, Hidden Sizes: 32, None, None, Batch Size: 32, Training Accuracy: 89.14%, Validation Accuracy: 84.71%, Precision: 84.72%, Recall: 84.71%, F1: 84.68%,loss_train:0.38553326105972346,loss_val:0.5165759284847379,weight_decay:1e-05
# Early stopping at epoch 97
# Learning Rate: 1e-05, Hidden Sizes: 64, None, None, Batch Size: 32, Training Accuracy: 94.17%, Validation Accuracy: 89.25%, Precision: 89.28%, Recall: 89.25%, F1: 89.25%,loss_train:0.2402066904984022,loss_val:0.3777042393004105,weight_decay:1e-05

# %%
param_grid = {
    'learning_rate': [0.00005],
    'hidden_size_layer1': [128,256,512],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 26
# Learning Rate: 5e-05, Hidden Sizes: 128, None, None, Batch Size: 32, Training Accuracy: 96.31%, Validation Accuracy: 91.23%, Precision: 91.31%, Recall: 91.23%, F1: 91.24%,loss_train:0.17384022890135098,loss_val:0.3248545288776465,weight_decay:1e-05
# Early stopping at epoch 32
# Learning Rate: 5e-05, Hidden Sizes: 256, None, None, Batch Size: 32, Training Accuracy: 98.22%, Validation Accuracy: 92.45%, Precision: 92.49%, Recall: 92.45%, F1: 92.45%,loss_train:0.12765836577649456,loss_val:0.296797258250893,weight_decay:1e-05
# Early stopping at epoch 33
# Learning Rate: 5e-05, Hidden Sizes: 512, None, None, Batch Size: 32, Training Accuracy: 98.59%, Validation Accuracy: 93.06%, Precision: 93.09%, Recall: 93.06%, F1: 93.05%,loss_train:0.12065658076096142,loss_val:0.28820541751718964,weight_decay:1e-05

# %% [markdown]
# Thử giảm learning rate xuống

# %%
param_grid = {
    'learning_rate': [0.00001],
    'hidden_size_layer1': [128,256,512],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 109
# Learning Rate: 1e-05, Hidden Sizes: 128, None, None, Batch Size: 32, Training Accuracy: 96.67%, Validation Accuracy: 91.28%, Precision: 91.29%, Recall: 91.28%, F1: 91.28%,loss_train:0.1688193077923622,loss_val:0.30759105348836363,weight_decay:1e-05
# Early stopping at epoch 109
# Learning Rate: 1e-05, Hidden Sizes: 256, None, None, Batch Size: 32, Training Accuracy: 97.51%, Validation Accuracy: 92.60%, Precision: 92.60%, Recall: 92.60%, F1: 92.59%,loss_train:0.14833049594225756,loss_val:0.2832861252671984,weight_decay:1e-05
# Early stopping at epoch 116
# Learning Rate: 1e-05, Hidden Sizes: 512, None, None, Batch Size: 32, Training Accuracy: 97.71%, Validation Accuracy: 92.70%, Precision: 92.72%, Recall: 92.70%, F1: 92.70%,loss_train:0.1427358094107711,loss_val:0.2814550698191907,weight_decay:1e-05

# %%
param_grid = {
    'learning_rate': [0.00001],
    'hidden_size_layer1': [512],
    'hidden_size_layer2': [None],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [64,128],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 115
# Learning Rate: 1e-05, Hidden Sizes: 512, None, None, Batch Size: 64, Training Accuracy: 97.54%, Validation Accuracy: 92.50%, Precision: 92.57%, Recall: 92.50%, F1: 92.51%,loss_train:0.14481967652789737,loss_val:0.2817788513646195,weight_decay:1e-05
# Early stopping at epoch 124
# Learning Rate: 1e-05, Hidden Sizes: 512, None, None, Batch Size: 128, Training Accuracy: 97.98%, Validation Accuracy: 92.81%, Precision: 92.82%, Recall: 92.81%, F1: 92.80%,loss_train:0.13750947638937763,loss_val:0.2797163002448782,weight_decay:1e-05

# %%
param_grid = {
    'learning_rate': [0.00001],
    'hidden_size_layer1': [128,256,512],
    'hidden_size_layer2': [128,256,512],  # None để biểu thị không có lớp thứ hai
    'hidden_size_layer3': [None],  # None để biểu thị không có lớp thứ ba
    #lý do chọn tối đa đến tầng thứ 3 là tránh overfitting và sử dụng hàm sigmoid đạo hàm của nó max là 0.25 nếu có quá nhiều lớp ẩn gradient nhân dần với nhau sẽ tiến tới 0(hiện tượng vanishing gradient)
    'batch_size': [32],
    'weight_decay':[0.00001],
    'epochs': [5000]#
    }
# Thử tất cả các kết hợp tham số
for learning_rate in param_grid['learning_rate']:
  for weight_decay in param_grid['weight_decay']:
    for hidden_size_layer3 in param_grid['hidden_size_layer3']:
        for hidden_size_layer2 in param_grid['hidden_size_layer2']:
            for hidden_size_layer1 in param_grid['hidden_size_layer1']:
                for batch_size in param_grid['batch_size']:
                    for epochs in param_grid['epochs']:
                        train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
                            hidden_size_layer1,
                            hidden_size_layer2,
                            hidden_size_layer3,
                            learning_rate,
                            batch_size,
                            x_train,
                            y_train_one_hot,
                            x_val,
                            y_val_one_hot,
                            epochs,
                            weight_decay
                        )
                        print(f'Learning Rate: {learning_rate}, Hidden Sizes: {hidden_size_layer1}, {hidden_size_layer2}, {hidden_size_layer3}, Batch Size: {batch_size}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Accuracy: {val_accuracy * 100:.2f}%, Precision: {precision * 100:.2f}%, Recall: {recall * 100:.2f}%, F1: {f1 * 100:.2f}%,loss_train:{loss_train},loss_val:{loss_val},weight_decay:{weight_decay}')
# Out:
# Early stopping at epoch 63
# Learning Rate: 1e-05, Hidden Sizes: 128, 128, None, Batch Size: 32, Training Accuracy: 95.94%, Validation Accuracy: 91.05%, Precision: 91.04%, Recall: 91.05%, F1: 91.03%,loss_train:0.17041878925743614,loss_val:0.3259536884931141,weight_decay:1e-05
# Early stopping at epoch 83
# Learning Rate: 1e-05, Hidden Sizes: 256, 128, None, Batch Size: 32, Training Accuracy: 98.07%, Validation Accuracy: 92.19%, Precision: 92.29%, Recall: 92.19%, F1: 92.20%,loss_train:0.11265272833164103,loss_val:0.29973539652646863,weight_decay:1e-05
# Early stopping at epoch 98
# Learning Rate: 1e-05, Hidden Sizes: 512, 128, None, Batch Size: 32, Training Accuracy: 98.18%, Validation Accuracy: 92.42%, Precision: 92.57%, Recall: 92.42%, F1: 92.45%,loss_train:0.11006996439069162,loss_val:0.30482490716333677,weight_decay:1e-05
# Early stopping at epoch 68
# Learning Rate: 1e-05, Hidden Sizes: 128, 256, None, Batch Size: 32, Training Accuracy: 96.62%, Validation Accuracy: 90.98%, Precision: 91.00%, Recall: 90.98%, F1: 90.98%,loss_train:0.1497235249477886,loss_val:0.32285236776163345,weight_decay:1e-05
# Early stopping at epoch 73
# Learning Rate: 1e-05, Hidden Sizes: 256, 256, None, Batch Size: 32, Training Accuracy: 97.08%, Validation Accuracy: 91.61%, Precision: 91.76%, Recall: 91.61%, F1: 91.63%,loss_train:0.1328379045414416,loss_val:0.31939562625714885,weight_decay:1e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-9720eb1cb227> in <cell line: 12>()
#      17                 for batch_size in param_grid['batch_size']:
#      18                     for epochs in param_grid['epochs']:
# ---> 19                         train_accuracy, val_accuracy, precision, recall, f1,loss_train,loss_val = evaluate_model(
#      20                             hidden_size_layer1,
#      21                             hidden_size_layer2,
#
# <ipython-input-20-a4e44cc50da0> in evaluate_model(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs, weight_decay, patience, min_delta)
#      18             batch_x = x_train[i * batch_size:(i + 1) * batch_size]
#      19             batch_y = y_train_one_hot[i * batch_size:(i + 1) * batch_size]
# ---> 20             model.train(batch_x, batch_y, 1)
#      21
#      22         # Đánh giá độ chính xác và loss trên tập validation
#
# <ipython-input-19-1d0fc509549b> in train(self, X, y, epochs)
#      76         for epoch in range(epochs):
#      77             self.forward(X)
# ---> 78             self.backward(X, y)
#      79
#      80     def evaluate(self, X, y):
#
# <ipython-input-19-1d0fc509549b> in backward(self, X, y)
#      62         for i in reversed(range(len(self.layers))):
#      63             if i == 0:
# ---> 64                 grad_hidden = X.T.dot(hidden_delta) + 2 * self.l2_lambda * self.layers[i]
#      65                 self.velocity_layers[i] = self.momentum * self.velocity_layers[i] - self.learning_rate * grad_hidden
#      66                 self.layers[i] += self.velocity_layers[i]
#
# KeyboardInterrupt:

# %% [markdown]
# Vậy Hyperparams là 512 ,batch size:128,learning rate:0.00001 ,momentum:0.99,weight-decay:0.00001

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Thay đổi: tạo range(epoch)
epochs_range = range(1, 120)

# Khởi tạo danh sách rỗng cho các chỉ số
train_loss, val_loss = [], []
train_accuracy, val_accuracy = [], []
train_recall, val_recall = [], []
train_f1, val_f1 = [], []
train_precision, val_precision = [], []

def evaluate_model_end(hidden_size_layer1, hidden_size_layer2, hidden_size_layer3, learning_rate, batch_size, x_train, y_train_one_hot, x_val, y_val_one_hot, epochs,weight_decay, patience=5, min_delta=0.001):
    model = SimpleNN(input_size=784,
                     hidden_size_layer1=hidden_size_layer1,
                     hidden_size_layer2=hidden_size_layer2,
                     hidden_size_layer3=hidden_size_layer3,
                     output_size=10,
                     learning_rate=learning_rate,
                     l2_lambda=weight_decay)
    best_accuracy = 0
    patience_counter = 0
    num_batches = int(np.ceil(len(x_train) / batch_size))

    for epoch in range(epochs):
        for i in range(num_batches):
            batch_x = x_train[i * batch_size:(i + 1) * batch_size]
            batch_y = y_train_one_hot[i * batch_size:(i + 1) * batch_size]
            model.train(batch_x, batch_y, 1)

        val_acc, val_loss_value = model.evaluate(x_val, y_val_one_hot)
        train_acc, train_loss_value = model.evaluate(x_train, y_train_one_hot)

        # Forward pass để lấy dự đoán
        train_predictions = model.forward(x_train)
        val_predictions = model.forward(x_val)

        # Chuyển đổi đầu ra thành nhãn phân loại
        train_predictions_labels = np.argmax(train_predictions, axis=1)
        val_predictions_labels = np.argmax(val_predictions, axis=1)
        true_labels_train = np.argmax(y_train_one_hot, axis=1)
        true_labels_val = np.argmax(y_val_one_hot, axis=1)

        # Tính toán các chỉ số
        precision_train = precision_score(true_labels_train, train_predictions_labels, average='weighted', zero_division=0)
        precision_val = precision_score(true_labels_val, val_predictions_labels, average='weighted', zero_division=0)
        recall_train = recall_score(true_labels_train, train_predictions_labels, average='weighted')
        recall_val = recall_score(true_labels_val, val_predictions_labels, average='weighted')
        f1_train = f1_score(true_labels_train, train_predictions_labels, average='weighted')
        f1_val = f1_score(true_labels_val, val_predictions_labels, average='weighted')

        # Append vào danh sách
        train_loss.append(train_loss_value)
        val_loss.append(val_loss_value)
        train_accuracy.append(train_acc)
        val_accuracy.append(val_acc)
        train_f1.append(f1_train)
        val_f1.append(f1_val)
        train_precision.append(precision_train)
        val_precision.append(precision_val)
        train_recall.append(recall_train)
        val_recall.append(recall_val)

    # Vẽ biểu đồ
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

    # Biểu đồ Loss & Accuracy
    ax1.plot(epochs_range, train_loss, 'b', label='Train Loss')
    ax1.plot(epochs_range, val_loss, 'g', label='Val Loss')
    ax1.plot(epochs_range, train_accuracy, 'c', label='Train Accuracy')
    ax1.plot(epochs_range, val_accuracy, 'r', label='Val Accuracy')
    ax1.set_title('Training and Validation Loss & Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss / Accuracy')
    ax1.legend()

    # Biểu đồ Recall, F1 Score và Precision
    ax2.plot(epochs_range, train_recall, 'c', label='Train Recall')
    ax2.plot(epochs_range, val_recall, 'm', label='Val Recall')
    ax2.plot(epochs_range, train_f1, 'y', label='Train F1 Score')
    ax2.plot(epochs_range, val_f1, 'k', label='Val F1 Score')
    ax2.plot(epochs_range, train_precision, 'g', label='Train Precision')
    ax2.plot(epochs_range, val_precision, 'r', label='Val Precision')
    ax2.set_title('Training and Validation Recall, F1 Score, & Precision')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Score')
    ax2.legend()

    plt.tight_layout()
    plt.show()

# %%
evaluate_model_end( 512,
                None,
                None,
                0.00001,
                128,
                x_train,
                y_train_one_hot,
                x_val,
                y_val_one_hot,
                epochs=119,
                weight_decay=0.00001)

# %%
x_train=np.concatenate([x_train, x_val])
y_train_one_hot=np.concatenate([y_train_one_hot, y_val_one_hot])
import joblib
final_model = SimpleNN(input_size=784,
                     hidden_size_layer1=512,
                     hidden_size_layer2=None,
                     hidden_size_layer3=None,
                     output_size=10,
                     learning_rate=0.00001, l2_lambda=0.00001)
num_batches = int(np.ceil(len(x_train) / 128))
for epoch in range(119):
    for i in range(num_batches):
        batch_x = x_train[i * 128:(i + 1) * 128]
        batch_y = y_train_one_hot[i * 128:(i + 1) * 128]  # Sử dụng nhãn one-hot
        final_model.train(batch_x, batch_y, 1)
joblib.dump(final_model, 'best_simple_nn_model.pkl')
print("Mô hình đã được lưu vào 'best_simple_nn_model.pkl'")
# Out:
# Mô hình đã được lưu vào 'best_simple_nn_model.pkl'

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# Dự đoán nhãn
y_pred = loaded_model.forward(x_test)

# Chuyển đổi từ one-hot encoding sang nhãn
y_test_labels = np.argmax(y_test_one_hot, axis=1)
y_pred_labels = np.argmax(y_pred, axis=1)

# Tạo Confusion Matrix
cm = confusion_matrix(y_test_labels, y_pred_labels)

# Hiển thị Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')  # Sử dụng bảng màu bạn muốn

# %%
# Tải mô hình
loaded_model = joblib.load('best_simple_nn_model.pkl')

# Sử dụng mô hình để dự đoán
test_accuracy,loss = loaded_model.evaluate(x_test, y_test_one_hot)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Loss: {loss}')
# Out:
# Test Accuracy: 89.75%
# Loss: 0.39374315305057445
